# %%
import os
import math
from numpy import * 
import pandas as pd
import time
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 若要測試單一個，請以以下方式引入單一資料集
# <span id="singleRunHead"></span>

# %%
# dir_data = '../datasets/'
# DATASET_CSV_NAME = '1_zoo.csv'
# DATASET_NAME = 'zoo'
# dir_train_test_data = f'../train_test_datasets/{DATASET_NAME}'
# train_data_loc = os.path.join(dir_data, DATASET_CSV_NAME)
# print('Path of read in data: %s' % (train_data_loc))
# data = pd.read_csv(train_data_loc)
# data.head()

# %%
len(data.columns)

# %%
# train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
# train_1 = pd.read_csv(train_1_data_loc)
# train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
# train_2 = pd.read_csv(train_2_data_loc)
# train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
# train_3 = pd.read_csv(train_3_data_loc)
# train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
# train_4 = pd.read_csv(train_4_data_loc)
# train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
# train_5 = pd.read_csv(train_5_data_loc)
# test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
# test_1 = pd.read_csv(test_1_data_loc)
# test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
# test_2 = pd.read_csv(test_2_data_loc)
# test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
# test_3 = pd.read_csv(test_3_data_loc)
# test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
# test_4 = pd.read_csv(test_4_data_loc)
# test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
# test_5 = pd.read_csv(test_5_data_loc)
# del train_1['numbers']
# del train_2['numbers']
# del train_3['numbers']
# del train_4['numbers']
# del train_5['numbers']
# del test_1['numbers']
# del test_2['numbers']
# del test_3['numbers']
# del test_4['numbers']
# del test_5['numbers']
# training_Data = []
# training_Data.append(train_1)
# training_Data.append(train_2)
# training_Data.append(train_3)
# training_Data.append(train_4)
# training_Data.append(train_5)
# testing_Data = []
# testing_Data.append(test_1)
# testing_Data.append(test_2)
# testing_Data.append(test_3)
# testing_Data.append(test_4)
# testing_Data.append(test_5)
# training_Data[0]

# %% [markdown]
# ### Library

# %%
from sklearn.feature_selection import mutual_info_classif, VarianceThreshold
from sklearn.feature_selection import chi2, f_classif
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import SelectKBest
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score, roc_curve, auc, f1_score, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, MinMaxScaler
import matplotlib.pyplot as plt
from ReliefF import ReliefF
from sklearn.linear_model import LassoCV, RidgeCV, Ridge
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ### Classifier

# %%
svm = SVC(kernel='rbf', probability=True, decision_function_shape='ovr', random_state=42) ## classifier
# knn = KNeighborsClassifier()
# svm = LinearSVC(multi_class='crammer_singer')

# %% [markdown]
# ### Datasets tags

# %%
DATASETS = [
    'Landsat',
    'soybean',
    'waveform',
    'Splice',
    'urban_land_cover',
    'SCADI', 
    'lung_discrete',
    'CNAE-9',
    'oh15','lung',
    'TOX_171',
    'orlraws10P',
    'CLL_SUB_111',
    'CARCINOM',
    'GLIOMA',
    'AllBooks_baseline_DTM_Labelled'
]
    
DATASETS_CSV = [
    '2_Landsat',
    '3_soybean', 
    '4_waveform',
    '5_Splice',
    '6_urban_land_cover',
    '7_SCADI',
    '9_lung_discrete',
    '11_CNAE-9',
    '12_oh15',
    '13_lung',
    '14_TOX_171',
    '15_orlraws10P',
    '16_CLL_SUB_111',
    'CARCINOM',
    'GLIOMA',
    'AllBooks_baseline_DTM_Labelled'
]

# %%
def loading_data(dir_train_test_data):    
    train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
    train_1 = pd.read_csv(train_1_data_loc)
    train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
    train_2 = pd.read_csv(train_2_data_loc)
    train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
    train_3 = pd.read_csv(train_3_data_loc)
    train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
    train_4 = pd.read_csv(train_4_data_loc)
    train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
    train_5 = pd.read_csv(train_5_data_loc)
    test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
    test_1 = pd.read_csv(test_1_data_loc)
    test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
    test_2 = pd.read_csv(test_2_data_loc)
    test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
    test_3 = pd.read_csv(test_3_data_loc)
    test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
    test_4 = pd.read_csv(test_4_data_loc)
    test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
    test_5 = pd.read_csv(test_5_data_loc)
    del train_1['numbers']
    del train_2['numbers']
    del train_3['numbers']
    del train_4['numbers']
    del train_5['numbers']
    del test_1['numbers']
    del test_2['numbers']
    del test_3['numbers']
    del test_4['numbers']
    del test_5['numbers']
    training_Data = []
    training_Data.append(train_1)
    training_Data.append(train_2)
    training_Data.append(train_3)
    training_Data.append(train_4)
    training_Data.append(train_5)
    testing_Data = []
    testing_Data.append(test_1)
    testing_Data.append(test_2)
    testing_Data.append(test_3)
    testing_Data.append(test_4)
    testing_Data.append(test_5)
    return training_Data, testing_Data

# %% [markdown]
# ### Feature Selection Algos

# %% [markdown]
# ### Filter 六合一都在下面這一個 cell，其他有要個別跑可個別呼叫，但還是都須先執行

# %%
def featureSelection(data_temp, filter_algo):
    if(filter_algo == 'reliefF'):
        selected_columns, len_selected = fs_reliefF(data_temp)
    elif(filter_algo == 'PCA'):
        selected_columns, len_selected = fs_PCA(data_temp)
    else:
        if(filter_algo == 'mi'): selector = SelectPercentile(mutual_info_classif, percentile=80) ## fs- selector
        elif(filter_algo == 'chi2') :selector = SelectPercentile(chi2, percentile=80) ## fs- selector
        elif(filter_algo == 'anova'): selector = SelectPercentile(f_classif, percentile=80) ## fs- selector
        elif(filter_algo == 'variance'): selector = VarianceThreshold(threshold=(0.8-(1*0.8)))
    ## fs
#     print("-------fs-------")
        data_ova = data_temp.copy()
    
        mms = pd.DataFrame(data=data_ova.drop(['class'], axis=1))
        data_mxs = MinMaxScaler().fit_transform(mms)
        data_mxs = pd.DataFrame(data=data_mxs, columns=data_ova.drop(['class'], axis=1).columns)
        data_mxs['class'] = data_ova['class']
    
#         del data_ova['class']
        del data_mxs['class']
        try:
            x_reduced = selector.fit_transform(data_mxs, data_temp['class'])
            cols = selector.get_support(indices=True)
            selected_columns = data_mxs.iloc[:,cols].columns.tolist()
        except:
            selected_columns = []
#     print(selected_columns)
    return selected_columns, len(selected_columns)

# %%
# n_components=332 must be between 0 and min(n_samples, n_features)=164
def fs_PCA(data_temp):
#     if(data_temp.columns > len(list(data_temp['class'])):
        
#     pca_components = min(len(list(data_temp['class'])), len(data_temp.columns)-2)
    try:
        
        limit = math.ceil(float(len(data_temp.columns)-2)*0.8)
        pca_components = limit

    #     pca_components=math.ceil((len(list(data_temp))-2)*0.5)
        n = pca_components
        pca = PCA(n_components=n)

        print("-------fs-------")
        data_ova = data_temp.copy()

        mms = pd.DataFrame(data=data_ova.drop(['class'], axis=1))
        data_mxs = MinMaxScaler().fit_transform(mms)
        data_mxs = pd.DataFrame(data=data_mxs, columns=data_ova.drop(['class'], axis=1).columns)
        data_mxs['class'] = data_ova['class']


        del data_mxs['class']
        pca.fit(data_mxs)
    except:
        pca_components = min(len(list(data_temp['class'])), len(data_temp.columns)-2)

    #     pca_components=math.ceil((len(list(data_temp))-2)*0.5)
        n = pca_components
        pca = PCA(n_components=n)

        print("-------fs-------")
        data_ova = data_temp.copy()

        mms = pd.DataFrame(data=data_ova.drop(['class'], axis=1))
        data_mxs = MinMaxScaler().fit_transform(mms)
        data_mxs = pd.DataFrame(data=data_mxs, columns=data_ova.drop(['class'], axis=1).columns)
        data_mxs['class'] = data_ova['class']


        del data_mxs['class']
        pca.fit(data_mxs)
    
    x_fit_train = pca.transform(data_mxs)
    pca_data = shape(x_fit_train)
    
    meanVals = mean(data_mxs, axis=0)
    dataAdjust = data_mxs - meanVals
    covMat = cov(dataAdjust, rowvar=0)
    eigVals, eigVects = linalg.eig(mat(covMat))
    eigVals =  eigVals.astype(float)
        
    eigVals_list=eigVals.tolist()
    feature_list = []
    feature_num=len(eigVals_list)
    for i in range(feature_num):
        feature_list.append(i)
#         print(feature_list)
    dict1 = dict(zip(feature_list, eigVals_list))
    a =  sorted(dict1.items(), key = lambda x: x[1], reverse=True)
    data_result_np=array(a)
#         print(data_result_np)
    data_feature_selection =data_result_np[:pca_data[1]]
#         print(data_feature_selection)
        
    data_list_divide = []
    for i in data_feature_selection:
        for j in i :
            data_list_divide.append(j)
        #print data_list_divide
    feature_list_result = []
    num = 0
    for f in data_list_divide:
        if (num != (int(pca_data[1]))*2):
            feature_list_result.append(int(data_list_divide[num]))  
            num = num + 2
        else:
            break
#         print ('feature_select_list :',feature_list_result)  #得知那些屬性被選擇了
        '''
        到這為止
        '''
    selected_columns = data_ova.iloc[:,feature_list_result].columns.tolist()
#     print(selected_columns)
    return selected_columns, len(selected_columns)

# %%
#  mms = pd.DataFrame(data=data_ova.drop(['class'], axis=1))
#         data_mxs = MinMaxScaler().fit_transform(mms)
#         data_mxs = pd.DataFrame(data=data_mxs, columns=data_ova.drop(['class'], axis=1).columns)
#         data_mxs['class'] = data_ova['class']

def fs_reliefF(data_temp):
     ## fs
    print("-------fs-------")
    data_ova = data_temp.copy()
    
    
    mms = pd.DataFrame(data=data_ova.drop(['class'], axis=1))
    data_mxs = MinMaxScaler().fit_transform(mms)
    data_mxs = pd.DataFrame(data=data_mxs, columns=data_ova.drop(['class'], axis=1).columns)
    data_mxs['class'] = data_ova['class']
    
#     del data_ova['class']
    del data_mxs['class']
        
    selector_reliefF = ReliefF(n_neighbors=1, n_features_to_keep=math.ceil((len(list(data))-1)*0.8))
     # fit_transform(x_train, y_train)
        
    d = data_mxs.copy()
    d = d.values
    feat = asarray(d)
    label = asarray(data_temp['class'])
        
    f = selector_reliefF.fit(feat, label)
    feature_list_result = f[0:math.ceil((len(list(data))-1)*0.8)]
#         print(f[0:8])
        
    selected_columns = data_ova.iloc[:,feature_list_result].columns.tolist()
#         print(selected_columns)    
#     print(selected_columns)
    return selected_columns, len(selected_columns)

# %% [markdown]
# ### train model

# %%
def train_test_clean(train_data, test_data, choosedFeature_AfterAction):
    temp = train_data.copy()
    del temp['class']
    temp_selected= temp[choosedFeature_AfterAction]
    x_train = temp_selected.sort_index(axis=1)
#     print(x_train) #80筆資料

    #把測試集手動取出與訓練集相同維度的所有資料
    temp_test = test_data.copy() #x_test
    del temp_test['class']
    temp_test_selected = temp_test[choosedFeature_AfterAction]
    x_test = temp_test_selected.sort_index(axis=1)
#     print(x_test)

    y_train = train_data['class']
    y_test = test_data['class']
    
    return x_train, x_test, y_train, y_test
def train_model(x_train, x_test, y_train, y_test, classifier):
    ## train model
#     print(x_train)
    classifier.fit(x_train, y_train)
    predicted = classifier.predict(x_test) # 預測的答案
    
#     print(predicted)
    '''-------------'''
#     predict_proba = classifier.predict_proba(x_test)
#     predict_proba = OneHotEncoder().fit_transform(predicted.reshape(-1,1)).toarray()
#     predict_proba = list(predict_proba)

#     not_predicted = []
#     for i in range(len(arange(1,7))):
#         if(i+1 not in predicted):
#             not_predicted.append(i+1)
# #     print(not_predicted)
#     if(not_predicted):
#         for i in range(len(not_predicted)):
#             for j in range(len(predict_proba)):
#                 predict_proba[j] = insert(predict_proba[j], not_predicted[i]-1, 0.)
#     print(predict_proba)
    '''-------------'''

    '''-------------'''
    lb = LabelBinarizer().fit(y_test)
    y_test_ = lb.transform(y_test)
    predict_proba = lb.transform(predicted)
    '''-------------'''

    y_test = array(list(y_test))
    predicted = array(list(predicted))
    y_train = array(list(y_train))
    
    # accuracy_train = svm.score(x_train, y_train) #x_train, y_train
    # print(accuracy_train)
#     rocaucscore = roc_auc_score(y_test_, predict_proba, multi_class='ovo',labels=arange(1,7), average='macro')
    rocaucscore = roc_auc_score(y_test_, predict_proba, average='macro')

    
    acc_scikit = accuracy_score(y_test, predicted)
#     accuracy_test = classifier.score(x_test, y_test) #x_test, y_test
    f1score = f1_score(y_test, predicted, average='macro')

    return acc_scikit, rocaucscore, f1score

def train_test_baseline(train_data, test_data):
    temp = train_data.copy()
    del temp['class']
    x_train = temp
    
    temp_test = test_data.copy()
    del temp_test['class']
    x_test = temp_test
    
    y_train = train_data['class']
    y_test = test_data['class']
    
    return x_train, x_test, y_train, y_test

# %% [markdown]
# ### 以下方式為跑結果，分為統整跑(一次跑全部)跟個別跑(跑單一資料集的單一演算法)

# %% [markdown]
# ### 1. 單一個別跑請參照以下，用途是作為確認程式碼是否OK時使用
# [並請確認有引入單一資料集->點我回上面](#singleRunHead)

# %%
accuracy_container = []
rocauc_container = []
f1score_container = []
acc_scikit_con = []
SUM_OF_COLUMNS = 0
for i in range(5):
    AfterFeatureSelection, len_of_columns = fs_PCA(training_Data[i])
    x_train, x_test, y_train, y_test = train_test_clean(training_Data[i], testing_Data[i], AfterFeatureSelection)
    SUM_OF_COLUMNS = SUM_OF_COLUMNS + len_of_columns
    acc_scikit, rocaucs, f1score = train_model(x_train, x_test, y_train, y_test, classifier)
    # print(accuracy_U)
    acc_scikit_con.append(acc_scikit)
#     accuracy_container.append(accuracy)
    rocauc_container.append(rocaucs)
    f1score_container.append(f1score)
    print(f'accuracy of fold {i+1}: {acc_scikit}')
    print(f'rocaucs of fold {i+1}: {rocaucs}')
avg_acc_scikit = sum(acc_scikit_con)/5
# avg_acc = sum(accuracy_container)/5
avg_rocauc = sum(rocauc_container)/5
avg_f1score = sum(f1score_container)/5
print('--------Baseline2 MI--------')
# print(f'avg_acc: {avg_acc}')
print(f'avg_acc_scikit: {avg_acc_scikit}')
print(f'avg_rocaucscore: {avg_rocauc}')
print(f'avg_f1score: {avg_f1score}')
print(f'avg_len: {SUM_OF_COLUMNS/5}')

# %% [markdown]
# ### 2. 統整跑需要先做讀寫檔案操作

# %%
# def writeFiles_Decom_UorI(STORE_PATH, DECOMPOSITION_TYPE, UorI, foldTurn, choosedFeature, f_len, spend_time, FS_METHOD):
def writeFiles_Decom_UorI(STORE_PATH, DECOMPOSITION_TYPE, UorI, foldTurn, choosedFeature, f_len, FS_METHOD):
    try:
        file_U = open(STORE_PATH + f'/{DECOMPOSITION_TYPE}/{UorI}/{FS_METHOD}_folds{foldTurn+1}.txt','w')
    except:
        os.makedirs(STORE_PATH + f'/{DECOMPOSITION_TYPE}/{UorI}')
        file_U = open(STORE_PATH + f'/{DECOMPOSITION_TYPE}/{UorI}/{FS_METHOD}_folds{foldTurn+1}.txt','w')
    choosedFeature = sorted(choosedFeature)
    for item in choosedFeature:
        file_U.write(item+"\n")
    file_U.write(str(f_len)+"\n")
#     file_U.write(str(spend_time)+"\n")
    file_U.close()

# %%
def readLines_UorI(STORE_PATH, DECOMPOSITION_TYPE, UorI, foldTurn, FS_METHOD):
    try:
        file1 = open(STORE_PATH + f'{DECOMPOSITION_TYPE}/{UorI}/{FS_METHOD}_folds{foldTurn+1}.txt', 'r')
        Lines = file1.readlines()
        choosedFeature = []
        for line in Lines:
            choosedFeature.append(line.strip())
        choosedFeature = choosedFeature[:-1]
#         choosedFeature = choosedFeature[:-2]
        fs_len = Lines[-1]
#         print(Lines[-2])
#         spend_time = Lines[-1]
#         print(Lines[-1])
        
        file1.close()
        return choosedFeature, fs_len
    except:
        return [], 0

# %%
result_baseline = pd.DataFrame(columns=['datasetName', 'algoName','acc_u','auc_u','f1_u', 'len', 'spend_time'])

# %% [markdown]
# ### Filter 統整跑

# %%
FILTER_ALGO=['mi','chi2', 'anova','reliefF','variance', 'PCA']
# FILTER_ALGO=['PCA']
classifier = svm
CLASSIFIER_STRING = "SVM"

# %%
dir_data = '../datasets/'
for qq in range(len(DATASETS)):
    DATASET_CSV_NAME = f'{DATASETS_CSV[qq]}.csv'
    DATASET_NAME = f'{DATASETS[qq]}'
    dir_train_test_data = f'../train_test_datasets/{DATASET_NAME}'

    train_data_loc = os.path.join(dir_data, DATASET_CSV_NAME)
    print('Path of read in data: %s' % (train_data_loc))
    data = pd.read_csv(train_data_loc)
    # data
    

    CLASS_AMOUNT = data['class'].value_counts().size
    FEATURE_AMOUNT = len(data.columns)-2

    # CLASS_AMOUNT

    train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
    train_1 = pd.read_csv(train_1_data_loc)
    train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
    train_2 = pd.read_csv(train_2_data_loc)
    train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
    train_3 = pd.read_csv(train_3_data_loc)
    train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
    train_4 = pd.read_csv(train_4_data_loc)
    train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
    train_5 = pd.read_csv(train_5_data_loc)
    test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
    test_1 = pd.read_csv(test_1_data_loc)
    test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
    test_2 = pd.read_csv(test_2_data_loc)
    test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
    test_3 = pd.read_csv(test_3_data_loc)
    test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
    test_4 = pd.read_csv(test_4_data_loc)
    test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
    test_5 = pd.read_csv(test_5_data_loc)
    del train_1['numbers']
    del train_2['numbers']
    del train_3['numbers']
    del train_4['numbers']
    del train_5['numbers']
    del test_1['numbers']
    del test_2['numbers']
    del test_3['numbers']
    del test_4['numbers']
    del test_5['numbers']
    training_Data = []
    training_Data.append(train_1)
    training_Data.append(train_2)
    training_Data.append(train_3)
    training_Data.append(train_4)
    training_Data.append(train_5)
    testing_Data = []
    testing_Data.append(test_1)
    testing_Data.append(test_2)
    testing_Data.append(test_3)
    testing_Data.append(test_4)
    testing_Data.append(test_5)
#     training_data, testing_data = loading_data(dir_train_test_data)
    ## 到此處應該大家都一樣
    
    spend_time = 0
    spend_time_container = []
    for zz in range(len(FILTER_ALGO)):
        STORE_PATH = f'./{FILTER_ALGO[zz]}_FILTER_v4_percent80_2023101/{DATASET_NAME}/'
        for i in range(5):
            start_time = time.time()
            AfterFeatureSelection, len_of_columns = featureSelection(training_Data[i], FILTER_ALGO[zz])
            end_time = time.time()
            spend_time = end_time - start_time
            if(AfterFeatureSelection!=[]):
                writeFiles_Decom_UorI(STORE_PATH, 'BASELINE', 'N', i, AfterFeatureSelection, len_of_columns, FILTER_ALGO[zz])
        spend_time = spend_time // 5
        spend_time_container.append(spend_time)
            
#     for kk in range(len(FILTER_ALGO)):
#             STORE_PATH = f'./{FILTER_ALGO[kk]}_FILTER_v2/{DATASET_NAME}/'
#             rocauc_container = []
#             f1score_container = []
#             acc_scikit_con = []
#             SUM_OF_COLUMNS = 0
#             total_spend_times = 0
#             for i in range(5):
#                 AfterFeatureSelection, len_of_columns , spend_time = readLines_UorI(STORE_PATH, 'BASELINE', 'N', i,FILTER_ALGO[kk])
#                 total_spend_times += float(spend_time)
#             #     print(AfterFeatureSelection)
#                 if(AfterFeatureSelection!=[]):
#                     x_train, x_test, y_train, y_test = train_test_clean(training_Data[i], testing_Data[i], AfterFeatureSelection)
#                     SUM_OF_COLUMNS = SUM_OF_COLUMNS + int(len_of_columns)
#                     acc_scikit, rocaucs, f1score = train_model(x_train, x_test, y_train, y_test, classifier)
#                     acc_scikit_con.append(acc_scikit)
#                     rocauc_container.append(rocaucs)
#                     f1score_container.append(f1score)
#                     print(f'accuracy of fold {i+1}: {acc_scikit}')
#                     print(f'rocaucs of fold {i+1}: {rocaucs}')
#                 else:
#                     acc_scikit_con.append(0)
#                     rocauc_container.append(0)
#                     f1score_container.append(0)

#                 #     accuracy_container.append(accuracy)
#             avg_acc_scikit = sum(acc_scikit_con)/5
#             # avg_acc = sum(accuracy_container)/5
#             avg_rocauc = sum(rocauc_container)/5
#             avg_f1score = sum(f1score_container)/5
#             print(f'--------Baseline2 filter {FILTER_ALGO[kk]}--------')
#             # print(f'avg_acc: {avg_acc}')
#             print(f'avg_acc_scikit: {avg_acc_scikit}')
#             print(f'avg_rocaucscore: {avg_rocauc}')
#             print(f'avg_f1score: {avg_f1score}')
#             print(f'avg_len: {SUM_OF_COLUMNS/5}')


#             t = pd.DataFrame([{'datasetName':DATASET_NAME,
#                              'algoName':FILTER_ALGO[kk],
#                              'acc_u':str(round(avg_acc_scikit,3)),
#                              'auc_u':str(round(avg_rocauc,3)),
#                              'f1_u':str(round(avg_f1score,3)),
#                               'len':str(round(SUM_OF_COLUMNS/5,3)),
#                               'spend_time': str(round(total_spend_times, 3)),
#                               'reductionRate':str(round((SUM_OF_COLUMNS/5)/FEATURE_AMOUNT, 3))
#                             }])
#             result_baseline = pd.concat([result_baseline, t]).reset_index(drop=True).astype('string')

    
# with pd.ExcelWriter(f'./result_excel_filter/result_baseline_fs_filter_{CLASSIFIER_STRING}.xlsx') as writer:
#     result_baseline.to_excel(writer, sheet_name='baseline_svm_fs')
# Out:
# Path of read in data: ../datasets/2_Landsat.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/3_soybean.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/4_waveform.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/5_Splice.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/6_urban_land_cover.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/7_SCADI.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/9_lung_discrete.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/11_CNAE-9.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/12_oh15.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/13_lung.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/14_TOX_171.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/15_orlraws10P.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/16_CLL_SUB_111.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/CARCINOM.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/GLIOMA.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# Path of read in data: ../datasets/AllBooks_baseline_DTM_Labelled.csv
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------
# -------fs-------

# %% [markdown]
# ### fs一次過後，之後全部的方法都只需要跑讀檔就好

# %%
dir_data = '../datasets/'
for qq in range(len(DATASETS)):
    DATASET_CSV_NAME = f'{DATASETS_CSV[qq]}.csv'
    DATASET_NAME = f'{DATASETS[qq]}'
    dir_train_test_data = f'../train_test_datasets/{DATASET_NAME}'

    train_data_loc = os.path.join(dir_data, DATASET_CSV_NAME)
    print('Path of read in data: %s' % (train_data_loc))
    data = pd.read_csv(train_data_loc)
    # data
    

    CLASS_AMOUNT = data['class'].value_counts().size
    FEATURE_AMOUNT = len(data.columns)-2
    
#     training_Data, testing_Data = loading_data(dir_train_test_data)
    train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
    train_1 = pd.read_csv(train_1_data_loc)
    train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
    train_2 = pd.read_csv(train_2_data_loc)
    train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
    train_3 = pd.read_csv(train_3_data_loc)
    train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
    train_4 = pd.read_csv(train_4_data_loc)
    train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
    train_5 = pd.read_csv(train_5_data_loc)
    test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
    test_1 = pd.read_csv(test_1_data_loc)
    test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
    test_2 = pd.read_csv(test_2_data_loc)
    test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
    test_3 = pd.read_csv(test_3_data_loc)
    test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
    test_4 = pd.read_csv(test_4_data_loc)
    test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
    test_5 = pd.read_csv(test_5_data_loc)
    del train_1['numbers']
    del train_2['numbers']
    del train_3['numbers']
    del train_4['numbers']
    del train_5['numbers']
    del test_1['numbers']
    del test_2['numbers']
    del test_3['numbers']
    del test_4['numbers']
    del test_5['numbers']
    training_Data = []
    training_Data.append(train_1)
    training_Data.append(train_2)
    training_Data.append(train_3)
    training_Data.append(train_4)
    training_Data.append(train_5)
    testing_Data = []
    testing_Data.append(test_1)
    testing_Data.append(test_2)
    testing_Data.append(test_3)
    testing_Data.append(test_4)
    testing_Data.append(test_5)
    
    for kk in range(len(FILTER_ALGO)):
            STORE_PATH = f'./{FILTER_ALGO[kk]}_FILTER_v4_percent80_2023101/{DATASET_NAME}/'
            rocauc_container = []
            f1score_container = []
            acc_scikit_con = []
            SUM_OF_COLUMNS = 0
#             total_spend_times = 0
            for i in range(5):
#                 AfterFeatureSelection, len_of_columns , spend_time = readLines_UorI(STORE_PATH, 'BASELINE', 'N', i,FILTER_ALGO[kk])
                AfterFeatureSelection, len_of_columns = readLines_UorI(STORE_PATH, 'BASELINE', 'N', i,FILTER_ALGO[kk])
#                 total_spend_times += spend_time
            #     print(AfterFeatureSelection)
                if(AfterFeatureSelection!=[]):
                    x_train, x_test, y_train, y_test = train_test_clean(training_Data[i], testing_Data[i], AfterFeatureSelection)
                    SUM_OF_COLUMNS = SUM_OF_COLUMNS + int(len_of_columns)
                    acc_scikit, rocaucs, f1score = train_model(x_train, x_test, y_train, y_test, classifier)
                    acc_scikit_con.append(acc_scikit)
                    rocauc_container.append(rocaucs)
                    f1score_container.append(f1score)
                    print(f'accuracy of fold {i+1}: {acc_scikit}')
                    print(f'rocaucs of fold {i+1}: {rocaucs}')
                else:
                    acc_scikit_con.append(0)
                    rocauc_container.append(0)
                    f1score_container.append(0)

                #     accuracy_container.append(accuracy)
            avg_acc_scikit = sum(acc_scikit_con)/5
            # avg_acc = sum(accuracy_container)/5
            avg_rocauc = sum(rocauc_container)/5
            avg_f1score = sum(f1score_container)/5
            print(f'--------Baseline2 filter {FILTER_ALGO[kk]}--------')
            # print(f'avg_acc: {avg_acc}')
            print(f'avg_acc_scikit: {avg_acc_scikit}')
            print(f'avg_rocaucscore: {avg_rocauc}')
            print(f'avg_f1score: {avg_f1score}')
            print(f'avg_len: {SUM_OF_COLUMNS/5}')


            t = pd.DataFrame([{'datasetName':DATASET_NAME,
                             'algoName':FILTER_ALGO[kk],
                             'acc_u':str(round(avg_acc_scikit,3)),
                             'auc_u':str(round(avg_rocauc,3)),
                             'f1_u':str(round(avg_f1score,3)),
                              'len':str(round(SUM_OF_COLUMNS/5,3)),
                              'spend_time': str(0),
                              'reductionRate':str(round((SUM_OF_COLUMNS/5)/FEATURE_AMOUNT, 3))
                            }])
            result_baseline = pd.concat([result_baseline, t]).reset_index(drop=True).astype('string')
# Out:
# Path of read in data: ../datasets/2_Landsat.csv
# accuracy of fold 1: 0.6944444444444444
# rocaucs of fold 1: 0.7624132261600293
# accuracy of fold 2: 0.7083333333333334
# rocaucs of fold 2: 0.7953267973856208
# accuracy of fold 3: 0.9305555555555556
# rocaucs of fold 3: 0.9528225806451612
# accuracy of fold 4: 0.6944444444444444
# rocaucs of fold 4: 0.790427807486631
# accuracy of fold 5: 0.7
# rocaucs of fold 5: 0.7908793393707186
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.7455555555555555
# avg_rocaucscore: 0.8183739502096323
# avg_f1score: 0.6193136592032362
# avg_len: 27.0
# accuracy of fold 1: 0.9444444444444444
# rocaucs of fold 1: 0.9621693121693121
# accuracy of fold 2: 1.0
# rocaucs of fold 2: 1.0
# accuracy of fold 3: 0.9583333333333334
# rocaucs of fold 3: 0.9722670250896058
# accuracy of fold 4: 0.9861111111111112
# rocaucs of fold 4: 0.9902777777777777
# accuracy of fold 5: 0.9857142857142858
# rocaucs of fold 5: 0.9893039591315453
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.974920634920635
# avg_rocaucscore: 0.9828036148336482
# avg_f1score: 0.9713920421969957
# avg_len: 27.0
# accuracy of fold 1: 0.9444444444444444
# rocaucs of fold 1: 0.9621693121693121
# accuracy of fold 2: 0.9861111111111112
# rocaucs of fold 2: 0.9902777777777777
# accuracy of fold 3: 0.9722222222222222
# rocaucs of fold 3: 0.9819892473118279
# accuracy of fold 4: 0.9861111111111112
# rocaucs of fold 4: 0.9902777777777777
# accuracy of fold 5: 0.9857142857142858
# rocaucs of fold 5: 0.9893039591315453
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.974920634920635
# avg_rocaucscore: 0.982803614833648
# avg_f1score: 0.9714563696823759
# avg_len: 27.0
# accuracy of fold 1: 0.5833333333333334
# rocaucs of fold 1: 0.6989795918367347
# accuracy of fold 2: 0.5555555555555556
# rocaucs of fold 2: 0.6966666666666667
# accuracy of fold 3: 0.5555555555555556
# rocaucs of fold 3: 0.6966666666666667
# accuracy of fold 4: 0.375
# rocaucs of fold 4: 0.6097360703812317
# accuracy of fold 5: 0.5571428571428572
# rocaucs of fold 5: 0.676068722943723
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.5253174603174603
# avg_rocaucscore: 0.6756235436990046
# avg_f1score: 0.3984001032479222
# avg_len: 4.0
# accuracy of fold 1: 0.6944444444444444
# rocaucs of fold 1: 0.7624132261600293
# accuracy of fold 2: 0.7083333333333334
# rocaucs of fold 2: 0.7953267973856208
# accuracy of fold 3: 0.7222222222222222
# rocaucs of fold 3: 0.8044444444444444
# accuracy of fold 4: 0.6944444444444444
# rocaucs of fold 4: 0.7907055852644088
# accuracy of fold 5: 0.6857142857142857
# rocaucs of fold 5: 0.7823729391617323
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.7010317460317461
# avg_rocaucscore: 0.7870525984832473
# avg_f1score: 0.5489627248450779
# avg_len: 34.0
# accuracy of fold 1: 0.9444444444444444
# rocaucs of fold 1: 0.9621693121693121
# accuracy of fold 2: 0.6805555555555556
# rocaucs of fold 2: 0.7769934640522876
# accuracy of fold 3: 0.9444444444444444
# rocaucs of fold 3: 0.9625448028673835
# accuracy of fold 4: 0.9722222222222222
# rocaucs of fold 4: 0.9851010101010101
# accuracy of fold 5: 0.6714285714285714
# rocaucs of fold 5: 0.7763731319765802
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.8426190476190477
# avg_rocaucscore: 0.8926363442333146
# avg_f1score: 0.7811874197597639
# avg_len: 27.0
# Path of read in data: ../datasets/3_soybean.csv
# accuracy of fold 1: 0.9557522123893806
# rocaucs of fold 1: 0.9565564706779531
# accuracy of fold 2: 0.9196428571428571
# rocaucs of fold 2: 0.9542618859994747
# accuracy of fold 3: 0.9017857142857143
# rocaucs of fold 3: 0.9628119254005779
# accuracy of fold 4: 0.9107142857142857
# rocaucs of fold 4: 0.9714998686629893
# accuracy of fold 5: 0.9196428571428571
# rocaucs of fold 5: 0.9542618859994747
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.921507585335019
# avg_rocaucscore: 0.9598784073480939
# avg_f1score: 0.934281686622397
# avg_len: 28.0
# accuracy of fold 1: 0.9823008849557522
# rocaucs of fold 1: 0.9959574468085106
# accuracy of fold 2: 0.8660714285714286
# rocaucs of fold 2: 0.9474586288416075
# accuracy of fold 3: 0.8214285714285714
# rocaucs of fold 3: 0.9559167323351719
# accuracy of fold 4: 0.8482142857142857
# rocaucs of fold 4: 0.9625361176779617
# accuracy of fold 5: 0.8928571428571429
# rocaucs of fold 5: 0.9541239821381666
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.8821744627054361
# avg_rocaucscore: 0.9631985815602837
# avg_f1score: 0.9379853542483468
# avg_len: 28.0
# accuracy of fold 1: 0.9646017699115044
# rocaucs of fold 1: 0.9652482269503546
# accuracy of fold 2: 0.9196428571428571
# rocaucs of fold 2: 0.9542618859994748
# accuracy of fold 3: 0.9017857142857143
# rocaucs of fold 3: 0.9692934068820594
# accuracy of fold 4: 0.9107142857142857
# rocaucs of fold 4: 0.9714539007092199
# accuracy of fold 5: 0.9196428571428571
# rocaucs of fold 5: 0.9542618859994747
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.9232774968394437
# avg_rocaucscore: 0.9629038613081168
# avg_f1score: 0.9408053331321374
# avg_len: 28.0
# accuracy of fold 1: 0.40707964601769914
# rocaucs of fold 1: 0.7021560252704114
# accuracy of fold 2: 0.4107142857142857
# rocaucs of fold 2: 0.7024303085017124
# accuracy of fold 3: 0.38392857142857145
# rocaucs of fold 3: 0.676442411908569
# accuracy of fold 4: 0.5
# rocaucs of fold 4: 0.7473342412163592
# accuracy of fold 5: 0.375
# rocaucs of fold 5: 0.6752698146745519
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.4153445006321112
# avg_rocaucscore: 0.7007265603143209
# avg_f1score: 0.36456185413077113
# avg_len: 4.0
# accuracy of fold 1: 0.9380530973451328
# rocaucs of fold 1: 0.9458472508197971
# accuracy of fold 2: 0.9285714285714286
# rocaucs of fold 2: 0.962949829261886
# accuracy of fold 3: 0.9107142857142857
# rocaucs of fold 3: 0.9650183871815078
# accuracy of fold 4: 0.9196428571428571
# rocaucs of fold 4: 0.9736603624901499
# accuracy of fold 5: 0.9196428571428571
# rocaucs of fold 5: 0.9542618859994747
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.9233249051833121
# avg_rocaucscore: 0.960347543150563
# avg_f1score: 0.9363125023170035
# avg_len: 35.0
# accuracy of fold 1: 0.9380530973451328
# rocaucs of fold 1: 0.9458960503513217
# accuracy of fold 2: 0.9196428571428571
# rocaucs of fold 2: 0.9542618859994747
# accuracy of fold 3: 0.9017857142857143
# rocaucs of fold 3: 0.9563764118728658
# accuracy of fold 4: 0.9107142857142857
# rocaucs of fold 4: 0.9714998686629893
# accuracy of fold 5: 0.875
# rocaucs of fold 5: 0.9349881796690308
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.9090391908975979
# avg_rocaucscore: 0.9526044793111363
# avg_f1score: 0.9193728665981528
# avg_len: 28.0
# Path of read in data: ../datasets/4_waveform.csv
# accuracy of fold 1: 0.8648648648648649
# rocaucs of fold 1: 0.8989906463042017
# accuracy of fold 2: 0.884
# rocaucs of fold 2: 0.9131788939822547
# accuracy of fold 3: 0.856
# rocaucs of fold 3: 0.892200995099536
# accuracy of fold 4: 0.874
# rocaucs of fold 4: 0.9057670750204064
# accuracy of fold 5: 0.873
# rocaucs of fold 5: 0.9048605270815452
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.870372972972973
# avg_rocaucscore: 0.9029996274975888
# avg_f1score: 0.8701399104676218
# avg_len: 32.0
# accuracy of fold 1: 0.8658658658658659
# rocaucs of fold 1: 0.8997456497895014
# accuracy of fold 2: 0.884
# rocaucs of fold 2: 0.9131762596977188
# accuracy of fold 3: 0.856
# rocaucs of fold 3: 0.8921697110222375
# accuracy of fold 4: 0.873
# rocaucs of fold 4: 0.9050222160371092
# accuracy of fold 5: 0.868
# rocaucs of fold 5: 0.9010997886310657
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.8693731731731733
# avg_rocaucscore: 0.9022427250355264
# avg_f1score: 0.869134177493952
# avg_len: 32.0
# accuracy of fold 1: 0.8658658658658659
# rocaucs of fold 1: 0.8997456497895014
# accuracy of fold 2: 0.884
# rocaucs of fold 2: 0.9131762596977188
# accuracy of fold 3: 0.856
# rocaucs of fold 3: 0.8921697110222375
# accuracy of fold 4: 0.873
# rocaucs of fold 4: 0.9050222160371092
# accuracy of fold 5: 0.865
# rocaucs of fold 5: 0.8988339276038753
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.8687731731731733
# avg_rocaucscore: 0.9017895528300883
# avg_f1score: 0.868528273329828
# avg_len: 32.0
# accuracy of fold 1: 0.5875875875875876
# rocaucs of fold 1: 0.6910114707098206
# accuracy of fold 2: 0.329
# rocaucs of fold 2: 0.49606940697993035
# accuracy of fold 3: 0.411
# rocaucs of fold 3: 0.5581493705333679
# accuracy of fold 4: 0.516
# rocaucs of fold 4: 0.6371919509304628
# accuracy of fold 5: 0.392
# rocaucs of fold 5: 0.5442981376619291
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.44711751751751755
# avg_rocaucscore: 0.5853440673631022
# avg_f1score: 0.43100468013547644
# avg_len: 5.0
# accuracy of fold 1: 0.8668668668668669
# rocaucs of fold 1: 0.9004628970490596
# accuracy of fold 2: 0.885
# rocaucs of fold 2: 0.9139211186810162
# accuracy of fold 3: 0.858
# rocaucs of fold 3: 0.8936907130661306
# accuracy of fold 4: 0.865
# rocaucs of fold 4: 0.8990505000851834
# accuracy of fold 5: 0.867
# rocaucs of fold 5: 0.9003445016220022
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.8683733733733734
# avg_rocaucscore: 0.9014939461006783
# avg_f1score: 0.8681304195932833
# avg_len: 40.0
# accuracy of fold 1: 0.7827827827827828
# rocaucs of fold 1: 0.8377199495942808
# accuracy of fold 2: 0.828
# rocaucs of fold 2: 0.8712331969054518
# accuracy of fold 3: 0.801
# rocaucs of fold 3: 0.8510079507472607
# accuracy of fold 4: 0.786
# rocaucs of fold 4: 0.8398899495235455
# accuracy of fold 5: 0.805
# rocaucs of fold 5: 0.853757315439331
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.8005565565565564
# avg_rocaucscore: 0.8507216724419738
# avg_f1score: 0.7997526287202295
# avg_len: 32.0
# Path of read in data: ../datasets/5_Splice.csv
# accuracy of fold 1: 0.8660436137071651
# rocaucs of fold 1: 0.8923521776186437
# accuracy of fold 2: 0.8414442700156985
# rocaucs of fold 2: 0.8664722223174168
# accuracy of fold 3: 0.8383045525902669
# rocaucs of fold 3: 0.860830790415423
# accuracy of fold 4: 0.8430141287284144
# rocaucs of fold 4: 0.8699543838686287
# accuracy of fold 5: 0.8618524332810047
# rocaucs of fold 5: 0.8851402846447032
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.8501317996645099
# avg_rocaucscore: 0.8749499717729631
# avg_f1score: 0.8347403909712684
# avg_len: 48.0
# accuracy of fold 1: 0.8753894080996885
# rocaucs of fold 1: 0.8999066604757072
# accuracy of fold 2: 0.847723704866562
# rocaucs of fold 2: 0.8708652799380138
# accuracy of fold 3: 0.8367346938775511
# rocaucs of fold 3: 0.8593971131796065
# accuracy of fold 4: 0.8430141287284144
# rocaucs of fold 4: 0.8713111643221341
# accuracy of fold 5: 0.8367346938775511
# rocaucs of fold 5: 0.8599980422564716
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.8479193258899533
# avg_rocaucscore: 0.8722956520343865
# avg_f1score: 0.8313658047580649
# avg_len: 48.0
# accuracy of fold 1: 0.8753894080996885
# rocaucs of fold 1: 0.8999066604757072
# accuracy of fold 2: 0.8383045525902669
# rocaucs of fold 2: 0.8632193775920451
# accuracy of fold 3: 0.82574568288854
# rocaucs of fold 3: 0.8505178432901102
# accuracy of fold 4: 0.8430141287284144
# rocaucs of fold 4: 0.8713111643221341
# accuracy of fold 5: 0.8367346938775511
# rocaucs of fold 5: 0.8599980422564716
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.8438376932368922
# avg_rocaucscore: 0.8689906175872937
# avg_f1score: 0.8272345716076878
# avg_len: 48.0
# accuracy of fold 1: 0.8940809968847352
# rocaucs of fold 1: 0.9238452198352052
# accuracy of fold 2: 0.9042386185243328
# rocaucs of fold 2: 0.9222283323511977
# accuracy of fold 3: 0.9309262166405023
# rocaucs of fold 3: 0.9487891228444081
# accuracy of fold 4: 0.8963893249607535
# rocaucs of fold 4: 0.9193911137482716
# accuracy of fold 5: 0.9120879120879121
# rocaucs of fold 5: 0.9301828281685949
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.9075446138196472
# avg_rocaucscore: 0.9288873233895355
# avg_f1score: 0.896076508258681
# avg_len: 7.0
# accuracy of fold 1: 0.8738317757009346
# rocaucs of fold 1: 0.8978805663181726
# accuracy of fold 2: 0.847723704866562
# rocaucs of fold 2: 0.8681063316384899
# accuracy of fold 3: 0.8288854003139717
# rocaucs of fold 3: 0.8535855074540311
# accuracy of fold 4: 0.8398744113029827
# rocaucs of fold 4: 0.8668715905738701
# accuracy of fold 5: 0.8445839874411303
# rocaucs of fold 5: 0.8712972863194199
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.8469798559251164
# avg_rocaucscore: 0.8715482564607967
# avg_f1score: 0.8309749585591769
# avg_len: 60.0
# accuracy of fold 1: 0.8130841121495327
# rocaucs of fold 1: 0.8475562954063909
# accuracy of fold 2: 0.7535321821036107
# rocaucs of fold 2: 0.7722402643057117
# accuracy of fold 3: 0.7660910518053375
# rocaucs of fold 3: 0.7925420687751658
# accuracy of fold 4: 0.7598116169544741
# rocaucs of fold 4: 0.7886404053241703
# accuracy of fold 5: 0.8571428571428571
# rocaucs of fold 5: 0.8780651755068932
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.7899323640311625
# avg_rocaucscore: 0.8158088418636662
# avg_f1score: 0.763129596266036
# avg_len: 48.0
# Path of read in data: ../datasets/6_urban_land_cover.csv
# accuracy of fold 1: 0.43884892086330934
# rocaucs of fold 1: 0.6334752930959806
# accuracy of fold 2: 0.41044776119402987
# rocaucs of fold 2: 0.6136822866588576
# accuracy of fold 3: 0.46875
# rocaucs of fold 3: 0.6468667545923685
# accuracy of fold 4: 0.43283582089552236
# rocaucs of fold 4: 0.6392216250229666
# accuracy of fold 5: 0.4626865671641791
# rocaucs of fold 5: 0.6499643009526619
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.44271381402340815
# avg_rocaucscore: 0.636642052064567
# avg_f1score: 0.2989604563129543
# avg_len: 117.0
# accuracy of fold 1: 0.43884892086330934
# rocaucs of fold 1: 0.6334752930959806
# accuracy of fold 2: 0.41044776119402987
# rocaucs of fold 2: 0.6136822866588576
# accuracy of fold 3: 0.46875
# rocaucs of fold 3: 0.6468667545923685
# accuracy of fold 4: 0.43283582089552236
# rocaucs of fold 4: 0.6392216250229666
# accuracy of fold 5: 0.4626865671641791
# rocaucs of fold 5: 0.6499643009526619
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.44271381402340815
# avg_rocaucscore: 0.636642052064567
# avg_f1score: 0.2989604563129543
# avg_len: 117.0
# accuracy of fold 1: 0.43884892086330934
# rocaucs of fold 1: 0.6315021308080537
# accuracy of fold 2: 0.41044776119402987
# rocaucs of fold 2: 0.6136822866588576
# accuracy of fold 3: 0.4765625
# rocaucs of fold 3: 0.6520162889902262
# accuracy of fold 4: 0.48507462686567165
# rocaucs of fold 4: 0.6649147133283217
# accuracy of fold 5: 0.4626865671641791
# rocaucs of fold 5: 0.6499643009526619
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.454724075217438
# avg_rocaucscore: 0.6424159441476242
# avg_f1score: 0.31699576189432455
# avg_len: 117.0
# accuracy of fold 1: 0.5539568345323741
# rocaucs of fold 1: 0.6881580544014815
# accuracy of fold 2: 0.6119402985074627
# rocaucs of fold 2: 0.7057531763543374
# accuracy of fold 3: 0.4375
# rocaucs of fold 3: 0.6007029812077231
# accuracy of fold 4: 0.5970149253731343
# rocaucs of fold 4: 0.7131284734891734
# accuracy of fold 5: 0.5671641791044776
# rocaucs of fold 5: 0.6973818881719304
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.5535152475034897
# avg_rocaucscore: 0.6810249147249292
# avg_f1score: 0.38042199563143925
# avg_len: 15.0
# accuracy of fold 1: 0.43884892086330934
# rocaucs of fold 1: 0.6334752930959806
# accuracy of fold 2: 0.41044776119402987
# rocaucs of fold 2: 0.6136822866588576
# accuracy of fold 3: 0.46875
# rocaucs of fold 3: 0.6468667545923685
# accuracy of fold 4: 0.43283582089552236
# rocaucs of fold 4: 0.6391764470167581
# accuracy of fold 5: 0.4626865671641791
# rocaucs of fold 5: 0.6499643009526619
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.44271381402340815
# avg_rocaucscore: 0.6366330164633254
# avg_f1score: 0.30012845665668164
# avg_len: 147.0
# accuracy of fold 1: 0.4244604316546763
# rocaucs of fold 1: 0.6334717819006648
# accuracy of fold 2: 0.39552238805970147
# rocaucs of fold 2: 0.6078926306534029
# accuracy of fold 3: 0.4921875
# rocaucs of fold 3: 0.6561059248225001
# accuracy of fold 4: 0.4925373134328358
# rocaucs of fold 4: 0.6623368107504193
# accuracy of fold 5: 0.48507462686567165
# rocaucs of fold 5: 0.658984152330151
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.45795645200257706
# avg_rocaucscore: 0.6437582600914277
# avg_f1score: 0.3198393199990615
# avg_len: 117.0
# Path of read in data: ../datasets/7_SCADI.csv
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6499771062271064
# accuracy of fold 2: 0.6875
# rocaucs of fold 2: 0.6901709401709403
# accuracy of fold 3: 0.7857142857142857
# rocaucs of fold 3: 0.7279040404040403
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.795138888888889
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.7244318181818182
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.7089285714285714
# avg_rocaucscore: 0.7175245587745589
# avg_f1score: 0.4328062678062679
# avg_len: 164.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6499771062271064
# accuracy of fold 2: 0.6875
# rocaucs of fold 2: 0.6901709401709403
# accuracy of fold 3: 0.7857142857142857
# rocaucs of fold 3: 0.7279040404040403
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.795138888888889
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.7244318181818182
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.7089285714285714
# avg_rocaucscore: 0.7175245587745589
# avg_f1score: 0.4328062678062679
# avg_len: 164.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6499771062271064
# accuracy of fold 2: 0.6875
# rocaucs of fold 2: 0.6901709401709403
# accuracy of fold 3: 0.7857142857142857
# rocaucs of fold 3: 0.7279040404040403
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.795138888888889
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.7244318181818182
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.7089285714285714
# avg_rocaucscore: 0.7175245587745589
# avg_f1score: 0.4328062678062679
# avg_len: 164.0
# accuracy of fold 1: 0.7222222222222222
# rocaucs of fold 1: 0.8684027777777777
# accuracy of fold 2: 0.8125
# rocaucs of fold 2: 0.7852564102564102
# accuracy of fold 3: 0.7142857142857143
# rocaucs of fold 3: 0.6868686868686869
# accuracy of fold 4: 0.8571428571428571
# rocaucs of fold 4: 0.8859508547008548
# accuracy of fold 5: 0.8571428571428571
# rocaucs of fold 5: 0.8153409090909091
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.7926587301587302
# avg_rocaucscore: 0.8083639277389277
# avg_f1score: 0.6142368742368742
# avg_len: 21.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6499771062271064
# accuracy of fold 2: 0.6875
# rocaucs of fold 2: 0.6901709401709403
# accuracy of fold 3: 0.7857142857142857
# rocaucs of fold 3: 0.7279040404040403
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.795138888888889
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.7244318181818182
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.7089285714285714
# avg_rocaucscore: 0.7175245587745589
# avg_f1score: 0.4328062678062679
# avg_len: 140.0
# accuracy of fold 1: 0.2222222222222222
# rocaucs of fold 1: 0.4894078144078144
# accuracy of fold 2: 0.5
# rocaucs of fold 2: 0.5760683760683761
# accuracy of fold 3: 0.7857142857142857
# rocaucs of fold 3: 0.7244318181818182
# accuracy of fold 4: 0.6428571428571429
# rocaucs of fold 4: 0.6202651515151515
# accuracy of fold 5: 0.7142857142857143
# rocaucs of fold 5: 0.6666666666666666
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.573015873015873
# avg_rocaucscore: 0.6153679653679653
# avg_f1score: 0.2897876100507679
# avg_len: 60.8
# Path of read in data: ../datasets/9_lung_discrete.csv
# accuracy of fold 1: 0.7058823529411765
# rocaucs of fold 1: 0.800595238095238
# accuracy of fold 2: 0.8571428571428571
# rocaucs of fold 2: 0.8435064935064934
# accuracy of fold 3: 0.9285714285714286
# rocaucs of fold 3: 0.9220779220779222
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.8132034632034632
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.8132034632034632
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.8126050420168067
# avg_rocaucscore: 0.838517316017316
# avg_f1score: 0.6777603349031921
# avg_len: 260.0
# accuracy of fold 1: 0.7058823529411765
# rocaucs of fold 1: 0.8020833333333333
# accuracy of fold 2: 0.8571428571428571
# rocaucs of fold 2: 0.8435064935064934
# accuracy of fold 3: 0.8571428571428571
# rocaucs of fold 3: 0.8435064935064936
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.8132034632034632
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.8132034632034632
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.7983193277310924
# avg_rocaucscore: 0.8231006493506493
# avg_f1score: 0.6449886621315193
# avg_len: 260.0
# accuracy of fold 1: 0.7058823529411765
# rocaucs of fold 1: 0.8020833333333333
# accuracy of fold 2: 0.8571428571428571
# rocaucs of fold 2: 0.8435064935064934
# accuracy of fold 3: 0.8571428571428571
# rocaucs of fold 3: 0.8435064935064936
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.8132034632034632
# accuracy of fold 5: 0.7857142857142857
# rocaucs of fold 5: 0.8132034632034632
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.7983193277310924
# avg_rocaucscore: 0.8231006493506493
# avg_f1score: 0.6449886621315193
# avg_len: 260.0
# accuracy of fold 1: 0.7647058823529411
# rocaucs of fold 1: 0.8452380952380952
# accuracy of fold 2: 0.6428571428571429
# rocaucs of fold 2: 0.703030303030303
# accuracy of fold 3: 0.8571428571428571
# rocaucs of fold 3: 0.8987262737262737
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.8132034632034632
# accuracy of fold 5: 0.7142857142857143
# rocaucs of fold 5: 0.7882034632034632
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.7529411764705882
# avg_rocaucscore: 0.8096803196803197
# avg_f1score: 0.6211791383219954
# avg_len: 33.0
# accuracy of fold 1: 0.7058823529411765
# rocaucs of fold 1: 0.800595238095238
# accuracy of fold 2: 0.8571428571428571
# rocaucs of fold 2: 0.8435064935064934
# accuracy of fold 3: 0.8571428571428571
# rocaucs of fold 3: 0.8435064935064936
# accuracy of fold 4: 0.7857142857142857
# rocaucs of fold 4: 0.8132034632034632
# accuracy of fold 5: 0.7142857142857143
# rocaucs of fold 5: 0.7346320346320346
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.7840336134453781
# avg_rocaucscore: 0.8070887445887447
# avg_f1score: 0.6149031920460492
# avg_len: 325.0
# accuracy of fold 1: 0.7058823529411765
# rocaucs of fold 1: 0.804421768707483
# accuracy of fold 2: 0.8571428571428571
# rocaucs of fold 2: 0.8435064935064934
# accuracy of fold 3: 0.9285714285714286
# rocaucs of fold 3: 0.922077922077922
# accuracy of fold 4: 0.9285714285714286
# rocaucs of fold 4: 0.922077922077922
# accuracy of fold 5: 0.8571428571428571
# rocaucs of fold 5: 0.8917748917748918
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.8554621848739495
# avg_rocaucscore: 0.8767717996289426
# avg_f1score: 0.7504988662131519
# avg_len: 58.4
# Path of read in data: ../datasets/11_CNAE-9.csv
# accuracy of fold 1: 0.9537037037037037
# rocaucs of fold 1: 0.9739583333333334
# accuracy of fold 2: 0.9027777777777778
# rocaucs of fold 2: 0.9453125
# accuracy of fold 3: 0.9120370370370371
# rocaucs of fold 3: 0.9505208333333334
# accuracy of fold 4: 0.9120370370370371
# rocaucs of fold 4: 0.9505208333333334
# accuracy of fold 5: 0.9120370370370371
# rocaucs of fold 5: 0.9505208333333334
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.9185185185185185
# avg_rocaucscore: 0.9541666666666668
# avg_f1score: 0.9193876269193518
# avg_len: 684.0
# accuracy of fold 1: 0.9490740740740741
# rocaucs of fold 1: 0.9713541666666666
# accuracy of fold 2: 0.9259259259259259
# rocaucs of fold 2: 0.9583333333333334
# accuracy of fold 3: 0.9259259259259259
# rocaucs of fold 3: 0.9583333333333334
# accuracy of fold 4: 0.9259259259259259
# rocaucs of fold 4: 0.9583333333333334
# accuracy of fold 5: 0.9305555555555556
# rocaucs of fold 5: 0.9609375
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.9314814814814815
# avg_rocaucscore: 0.9614583333333334
# avg_f1score: 0.9320110980288308
# avg_len: 684.0
# accuracy of fold 1: 0.9398148148148148
# rocaucs of fold 1: 0.9661458333333334
# accuracy of fold 2: 0.9212962962962963
# rocaucs of fold 2: 0.9557291666666666
# accuracy of fold 3: 0.9259259259259259
# rocaucs of fold 3: 0.9583333333333334
# accuracy of fold 4: 0.9259259259259259
# rocaucs of fold 4: 0.9583333333333334
# accuracy of fold 5: 0.9259259259259259
# rocaucs of fold 5: 0.9583333333333334
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.9277777777777778
# avg_rocaucscore: 0.959375
# avg_f1score: 0.928626776136819
# avg_len: 684.0
# accuracy of fold 1: 0.32407407407407407
# rocaucs of fold 1: 0.6197916666666666
# accuracy of fold 2: 0.2037037037037037
# rocaucs of fold 2: 0.5520833333333334
# accuracy of fold 3: 0.37037037037037035
# rocaucs of fold 3: 0.6458333333333334
# accuracy of fold 4: 0.3333333333333333
# rocaucs of fold 4: 0.625
# accuracy of fold 5: 0.32407407407407407
# rocaucs of fold 5: 0.6197916666666666
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.31111111111111106
# avg_rocaucscore: 0.6125
# avg_f1score: 0.29174259949607695
# avg_len: 86.0
# accuracy of fold 1: 0.9398148148148148
# rocaucs of fold 1: 0.9661458333333334
# accuracy of fold 2: 0.9027777777777778
# rocaucs of fold 2: 0.9453125
# accuracy of fold 3: 0.9259259259259259
# rocaucs of fold 3: 0.9583333333333334
# accuracy of fold 4: 0.9259259259259259
# rocaucs of fold 4: 0.9583333333333334
# accuracy of fold 5: 0.9259259259259259
# rocaucs of fold 5: 0.9583333333333334
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.924074074074074
# avg_rocaucscore: 0.9572916666666668
# avg_f1score: 0.9249088366766955
# avg_len: 775.4
# accuracy of fold 1: 0.9027777777777778
# rocaucs of fold 1: 0.9453125
# accuracy of fold 2: 0.8611111111111112
# rocaucs of fold 2: 0.921875
# accuracy of fold 3: 0.8842592592592593
# rocaucs of fold 3: 0.9348958333333334
# accuracy of fold 4: 0.8796296296296297
# rocaucs of fold 4: 0.9322916666666666
# accuracy of fold 5: 0.8796296296296297
# rocaucs of fold 5: 0.9322916666666666
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.8814814814814815
# avg_rocaucscore: 0.9333333333333333
# avg_f1score: 0.8819123034769829
# avg_len: 684.0
# Path of read in data: ../datasets/12_oh15.csv
# accuracy of fold 1: 0.7357512953367875
# rocaucs of fold 1: 0.8198356484526907
# accuracy of fold 2: 0.7277777777777777
# rocaucs of fold 2: 0.8187628568339612
# accuracy of fold 3: 0.7388888888888889
# rocaucs of fold 3: 0.8263623209275701
# accuracy of fold 4: 0.7
# rocaucs of fold 4: 0.7888591841951882
# accuracy of fold 5: 0.6944444444444444
# rocaucs of fold 5: 0.7867248601980875
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.7193724812895799
# avg_rocaucscore: 0.8081089741214995
# avg_f1score: 0.6826783513732847
# avg_len: 2480.0
# accuracy of fold 1: 0.7512953367875648
# rocaucs of fold 1: 0.8314968031517989
# accuracy of fold 2: 0.7388888888888889
# rocaucs of fold 2: 0.8342973316561764
# accuracy of fold 3: 0.7444444444444445
# rocaucs of fold 3: 0.8325114376745821
# accuracy of fold 4: 0.7277777777777777
# rocaucs of fold 4: 0.8080050020186361
# accuracy of fold 5: 0.7055555555555556
# rocaucs of fold 5: 0.7946202313220387
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.7335924006908463
# avg_rocaucscore: 0.8201861611646464
# avg_f1score: 0.7032811525682281
# avg_len: 2480.0
# accuracy of fold 1: 0.7409326424870466
# rocaucs of fold 1: 0.8266634354714218
# accuracy of fold 2: 0.7444444444444445
# rocaucs of fold 2: 0.8297278785483929
# accuracy of fold 3: 0.7444444444444445
# rocaucs of fold 3: 0.8329468056096152
# accuracy of fold 4: 0.7111111111111111
# rocaucs of fold 4: 0.7969702343052829
# accuracy of fold 5: 0.6888888888888889
# rocaucs of fold 5: 0.7860366312225282
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.7259643062751872
# avg_rocaucscore: 0.814468997031448
# avg_f1score: 0.6927793721467739
# avg_len: 2480.0
# accuracy of fold 1: 0.7150259067357513
# rocaucs of fold 1: 0.8176629084415701
# accuracy of fold 2: 0.7333333333333333
# rocaucs of fold 2: 0.8323449155272329
# accuracy of fold 3: 0.7166666666666667
# rocaucs of fold 3: 0.8194109822687592
# accuracy of fold 4: 0.6888888888888889
# rocaucs of fold 4: 0.7793304168364913
# accuracy of fold 5: 0.6666666666666666
# rocaucs of fold 5: 0.7671185316008293
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.7041162924582614
# avg_rocaucscore: 0.8031735509349766
# avg_f1score: 0.6660802071463747
# avg_len: 311.0
# accuracy of fold 1: 0.7409326424870466
# rocaucs of fold 1: 0.8245583544650856
# accuracy of fold 2: 0.7055555555555556
# rocaucs of fold 2: 0.8082083415900762
# accuracy of fold 3: 0.7388888888888889
# rocaucs of fold 3: 0.8285183611298406
# accuracy of fold 4: 0.7111111111111111
# rocaucs of fold 4: 0.7957384607480977
# accuracy of fold 5: 0.6888888888888889
# rocaucs of fold 5: 0.7830092999097229
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.7170754173862983
# avg_rocaucscore: 0.8080065635685646
# avg_f1score: 0.6845342163166815
# avg_len: 3093.2
# accuracy of fold 1: 0.5854922279792746
# rocaucs of fold 1: 0.7216531154762376
# accuracy of fold 2: 0.5944444444444444
# rocaucs of fold 2: 0.7279395443808843
# accuracy of fold 3: 0.5722222222222222
# rocaucs of fold 3: 0.7186388495773625
# accuracy of fold 4: 0.5333333333333333
# rocaucs of fold 4: 0.689948858954911
# accuracy of fold 5: 0.5722222222222222
# rocaucs of fold 5: 0.6990850004093427
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.5715428900402995
# avg_rocaucscore: 0.7114530737597476
# avg_f1score: 0.4933303644350187
# avg_len: 730.4
# Path of read in data: ../datasets/13_lung.csv
# accuracy of fold 1: 0.925
# rocaucs of fold 1: 0.8582089782089781
# accuracy of fold 2: 0.95
# rocaucs of fold 2: 0.8583333333333334
# accuracy of fold 3: 0.9487179487179487
# rocaucs of fold 3: 0.8583333333333334
# accuracy of fold 4: 0.926829268292683
# rocaucs of fold 4: 0.8533412533412534
# accuracy of fold 5: 0.9523809523809523
# rocaucs of fold 5: 0.8857142857142858
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.9405856338783168
# avg_rocaucscore: 0.8627862367862369
# avg_f1score: 0.7597796947960287
# avg_len: 2649.0
# accuracy of fold 1: 0.925
# rocaucs of fold 1: 0.8582089782089781
# accuracy of fold 2: 0.95
# rocaucs of fold 2: 0.8583333333333334
# accuracy of fold 3: 0.9487179487179487
# rocaucs of fold 3: 0.8583333333333334
# accuracy of fold 4: 0.926829268292683
# rocaucs of fold 4: 0.8533412533412534
# accuracy of fold 5: 0.9285714285714286
# rocaucs of fold 5: 0.8535714285714284
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.9358237291164121
# avg_rocaucscore: 0.8563576653576653
# avg_f1score: 0.7534108211214858
# avg_len: 2649.0
# accuracy of fold 1: 0.925
# rocaucs of fold 1: 0.8582089782089781
# accuracy of fold 2: 0.95
# rocaucs of fold 2: 0.8583333333333334
# accuracy of fold 3: 0.9487179487179487
# rocaucs of fold 3: 0.8583333333333334
# accuracy of fold 4: 0.9512195121951219
# rocaucs of fold 4: 0.8596153846153847
# accuracy of fold 5: 0.9523809523809523
# rocaucs of fold 5: 0.8857142857142858
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.9454636826588046
# avg_rocaucscore: 0.8640410630410631
# avg_f1score: 0.7649500920535403
# avg_len: 2649.0
# accuracy of fold 1: 0.9
# rocaucs of fold 1: 0.8305166705166706
# accuracy of fold 2: 0.95
# rocaucs of fold 2: 0.8638888888888889
# accuracy of fold 3: 0.9743589743589743
# rocaucs of fold 3: 0.9666666666666666
# accuracy of fold 4: 0.9024390243902439
# rocaucs of fold 4: 0.8470671220671221
# accuracy of fold 5: 0.9285714285714286
# rocaucs of fold 5: 0.8535714285714284
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.9310738854641294
# avg_rocaucscore: 0.8723421553421552
# avg_f1score: 0.7798069158515188
# avg_len: 332.0
# accuracy of fold 1: 0.925
# rocaucs of fold 1: 0.8582089782089781
# accuracy of fold 2: 0.95
# rocaucs of fold 2: 0.8583333333333334
# accuracy of fold 3: 0.9487179487179487
# rocaucs of fold 3: 0.8583333333333334
# accuracy of fold 4: 0.9512195121951219
# rocaucs of fold 4: 0.8596153846153847
# accuracy of fold 5: 0.9285714285714286
# rocaucs of fold 5: 0.8535714285714284
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.9407017778968999
# avg_rocaucscore: 0.8576124916124916
# avg_f1score: 0.7585812183789973
# avg_len: 3312.0
# accuracy of fold 1: 0.775
# rocaucs of fold 1: 0.6737217987217987
# accuracy of fold 2: 0.8
# rocaucs of fold 2: 0.6333333333333334
# accuracy of fold 3: 0.8205128205128205
# rocaucs of fold 3: 0.675
# accuracy of fold 4: 0.7560975609756098
# rocaucs of fold 4: 0.5980769230769231
# accuracy of fold 5: 0.7619047619047619
# rocaucs of fold 5: 0.6285714285714286
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.7827030286786384
# avg_rocaucscore: 0.6417406967406968
# avg_f1score: 0.4076250798381945
# avg_len: 163.2
# Path of read in data: ../datasets/14_TOX_171.csv
# accuracy of fold 1: 0.7142857142857143
# rocaucs of fold 1: 0.7878418803418803
# accuracy of fold 2: 0.5294117647058824
# rocaucs of fold 2: 0.6821527777777777
# accuracy of fold 3: 0.35294117647058826
# rocaucs of fold 3: 0.5682371794871794
# accuracy of fold 4: 0.5
# rocaucs of fold 4: 0.6655769230769231
# accuracy of fold 5: 0.5294117647058824
# rocaucs of fold 5: 0.6854273504273505
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.5252100840336135
# avg_rocaucscore: 0.6778472222222223
# avg_f1score: 0.4381083561747177
# avg_len: 4598.0
# accuracy of fold 1: 0.6857142857142857
# rocaucs of fold 1: 0.7691452991452992
# accuracy of fold 2: 0.5294117647058824
# rocaucs of fold 2: 0.6821527777777778
# accuracy of fold 3: 0.35294117647058826
# rocaucs of fold 3: 0.5682371794871794
# accuracy of fold 4: 0.5
# rocaucs of fold 4: 0.6655769230769231
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.6665384615384615
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.5136134453781513
# avg_rocaucscore: 0.6703301282051282
# avg_f1score: 0.4303511050353156
# avg_len: 4598.0
# accuracy of fold 1: 0.6857142857142857
# rocaucs of fold 1: 0.7691452991452992
# accuracy of fold 2: 0.5294117647058824
# rocaucs of fold 2: 0.6821527777777778
# accuracy of fold 3: 0.35294117647058826
# rocaucs of fold 3: 0.5682371794871794
# accuracy of fold 4: 0.5
# rocaucs of fold 4: 0.6655769230769231
# accuracy of fold 5: 0.5294117647058824
# rocaucs of fold 5: 0.6854273504273505
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.5194957983193278
# avg_rocaucscore: 0.674107905982906
# avg_f1score: 0.4338755805597911
# avg_len: 4598.0
# accuracy of fold 1: 0.4857142857142857
# rocaucs of fold 1: 0.6378846153846154
# accuracy of fold 2: 0.35294117647058826
# rocaucs of fold 2: 0.5645726495726495
# accuracy of fold 3: 0.35294117647058826
# rocaucs of fold 3: 0.5682371794871794
# accuracy of fold 4: 0.47058823529411764
# rocaucs of fold 4: 0.6470726495726495
# accuracy of fold 5: 0.47058823529411764
# rocaucs of fold 5: 0.6466826923076923
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.4265546218487395
# avg_rocaucscore: 0.6128899572649573
# avg_f1score: 0.3599720549177071
# avg_len: 575.0
# accuracy of fold 1: 0.6857142857142857
# rocaucs of fold 1: 0.7691452991452992
# accuracy of fold 2: 0.5294117647058824
# rocaucs of fold 2: 0.6821527777777777
# accuracy of fold 3: 0.35294117647058826
# rocaucs of fold 3: 0.5682371794871794
# accuracy of fold 4: 0.5
# rocaucs of fold 4: 0.6655769230769231
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.6665384615384615
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.5136134453781513
# avg_rocaucscore: 0.6703301282051282
# avg_f1score: 0.42956595705337125
# avg_len: 5748.0
# accuracy of fold 1: 0.2857142857142857
# rocaucs of fold 1: 0.5298840048840049
# accuracy of fold 2: 0.35294117647058826
# rocaucs of fold 2: 0.5628365384615385
# accuracy of fold 3: 0.3235294117647059
# rocaucs of fold 3: 0.5429861111111112
# accuracy of fold 4: 0.35294117647058826
# rocaucs of fold 4: 0.5622596153846154
# accuracy of fold 5: 0.14705882352941177
# rocaucs of fold 5: 0.42444444444444446
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.2924369747899159
# avg_rocaucscore: 0.5244821428571429
# avg_f1score: 0.25722294114927713
# avg_len: 136.8
# Path of read in data: ../datasets/15_orlraws10P.csv
# accuracy of fold 1: 1.0
# rocaucs of fold 1: 1.0
# accuracy of fold 2: 1.0
# rocaucs of fold 2: 1.0
# accuracy of fold 3: 1.0
# rocaucs of fold 3: 1.0
# accuracy of fold 4: 0.9
# rocaucs of fold 4: 0.9444444444444444
# accuracy of fold 5: 0.9
# rocaucs of fold 5: 0.9444444444444444
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.96
# avg_rocaucscore: 0.9777777777777779
# avg_f1score: 0.9466666666666667
# avg_len: 8243.0
# accuracy of fold 1: 1.0
# rocaucs of fold 1: 1.0
# accuracy of fold 2: 1.0
# rocaucs of fold 2: 1.0
# accuracy of fold 3: 0.95
# rocaucs of fold 3: 0.9722222222222221
# accuracy of fold 4: 0.95
# rocaucs of fold 4: 0.9722222222222221
# accuracy of fold 5: 0.9
# rocaucs of fold 5: 0.9444444444444444
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.9600000000000002
# avg_rocaucscore: 0.9777777777777779
# avg_f1score: 0.952
# avg_len: 8243.0
# accuracy of fold 1: 0.95
# rocaucs of fold 1: 0.9722222222222221
# accuracy of fold 2: 1.0
# rocaucs of fold 2: 1.0
# accuracy of fold 3: 0.95
# rocaucs of fold 3: 0.9722222222222221
# accuracy of fold 4: 1.0
# rocaucs of fold 4: 1.0
# accuracy of fold 5: 0.9
# rocaucs of fold 5: 0.9444444444444444
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.96
# avg_rocaucscore: 0.9777777777777776
# avg_f1score: 0.952
# avg_len: 8243.0
# accuracy of fold 1: 0.95
# rocaucs of fold 1: 0.9722222222222221
# accuracy of fold 2: 1.0
# rocaucs of fold 2: 1.0
# accuracy of fold 3: 1.0
# rocaucs of fold 3: 1.0
# accuracy of fold 4: 1.0
# rocaucs of fold 4: 1.0
# accuracy of fold 5: 0.95
# rocaucs of fold 5: 0.9722222222222221
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.9800000000000001
# avg_rocaucscore: 0.9888888888888889
# avg_f1score: 0.9786666666666667
# avg_len: 1031.0
# accuracy of fold 1: 0.95
# rocaucs of fold 1: 0.9722222222222221
# accuracy of fold 2: 1.0
# rocaucs of fold 2: 1.0
# accuracy of fold 3: 0.95
# rocaucs of fold 3: 0.9722222222222221
# accuracy of fold 4: 0.9
# rocaucs of fold 4: 0.9444444444444444
# accuracy of fold 5: 0.9
# rocaucs of fold 5: 0.9444444444444444
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.9400000000000001
# avg_rocaucscore: 0.9666666666666666
# avg_f1score: 0.9253333333333333
# avg_len: 10304.0
# accuracy of fold 1: 0.55
# rocaucs of fold 1: 0.75
# accuracy of fold 2: 0.65
# rocaucs of fold 2: 0.8055555555555556
# accuracy of fold 3: 0.8
# rocaucs of fold 3: 0.888888888888889
# accuracy of fold 4: 0.75
# rocaucs of fold 4: 0.861111111111111
# accuracy of fold 5: 0.7
# rocaucs of fold 5: 0.8333333333333334
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.6900000000000001
# avg_rocaucscore: 0.8277777777777778
# avg_f1score: 0.6727619047619048
# avg_len: 80.0
# Path of read in data: ../datasets/16_CLL_SUB_111.csv
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6610398860398861
# accuracy of fold 2: 0.5454545454545454
# rocaucs of fold 2: 0.6944444444444443
# accuracy of fold 3: 0.4090909090909091
# rocaucs of fold 3: 0.6027777777777777
# accuracy of fold 4: 0.45454545454545453
# rocaucs of fold 4: 0.5
# accuracy of fold 5: 0.43478260869565216
# rocaucs of fold 5: 0.47309634809634815
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.4687747035573123
# avg_rocaucscore: 0.5862716912716912
# avg_f1score: 0.4303675856307435
# avg_len: 9072.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6610398860398861
# accuracy of fold 2: 0.5454545454545454
# rocaucs of fold 2: 0.6944444444444443
# accuracy of fold 3: 0.4090909090909091
# rocaucs of fold 3: 0.6027777777777777
# accuracy of fold 4: 0.45454545454545453
# rocaucs of fold 4: 0.5
# accuracy of fold 5: 0.391304347826087
# rocaucs of fold 5: 0.44512432012432007
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.4600790513833992
# avg_rocaucscore: 0.5806772856772857
# avg_f1score: 0.4274105963834317
# avg_len: 9072.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6610398860398861
# accuracy of fold 2: 0.5454545454545454
# rocaucs of fold 2: 0.6944444444444443
# accuracy of fold 3: 0.4090909090909091
# rocaucs of fold 3: 0.6027777777777777
# accuracy of fold 4: 0.45454545454545453
# rocaucs of fold 4: 0.5
# accuracy of fold 5: 0.391304347826087
# rocaucs of fold 5: 0.44512432012432007
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.4600790513833992
# avg_rocaucscore: 0.5806772856772857
# avg_f1score: 0.4274105963834317
# avg_len: 9072.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6610398860398861
# accuracy of fold 2: 0.5454545454545454
# rocaucs of fold 2: 0.6944444444444443
# accuracy of fold 3: 0.4090909090909091
# rocaucs of fold 3: 0.6027777777777777
# accuracy of fold 4: 0.45454545454545453
# rocaucs of fold 4: 0.5
# accuracy of fold 5: 0.4782608695652174
# rocaucs of fold 5: 0.5036519036519036
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.4774703557312253
# avg_rocaucscore: 0.5923828023828024
# avg_f1score: 0.4419680819086591
# avg_len: 1135.0
# accuracy of fold 1: 0.5
# rocaucs of fold 1: 0.6610398860398861
# accuracy of fold 2: 0.5454545454545454
# rocaucs of fold 2: 0.6944444444444443
# accuracy of fold 3: 0.4090909090909091
# rocaucs of fold 3: 0.6027777777777777
# accuracy of fold 4: 0.45454545454545453
# rocaucs of fold 4: 0.5
# accuracy of fold 5: 0.43478260869565216
# rocaucs of fold 5: 0.47309634809634815
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.4687747035573123
# avg_rocaucscore: 0.5862716912716912
# avg_f1score: 0.4303675856307435
# avg_len: 11340.0
# accuracy of fold 1: 0.7272727272727273
# rocaucs of fold 1: 0.8143162393162392
# accuracy of fold 2: 0.6818181818181818
# rocaucs of fold 2: 0.7861111111111111
# accuracy of fold 3: 0.5909090909090909
# rocaucs of fold 3: 0.725
# accuracy of fold 4: 0.6818181818181818
# rocaucs of fold 4: 0.6527777777777778
# accuracy of fold 5: 0.6086956521739131
# rocaucs of fold 5: 0.5963869463869463
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.658102766798419
# avg_rocaucscore: 0.7149184149184149
# avg_f1score: 0.6107934835992789
# avg_len: 88.8
# Path of read in data: ../datasets/CARCINOM.csv
# accuracy of fold 1: 0.7631578947368421
# rocaucs of fold 1: 0.8327728174603173
# accuracy of fold 2: 0.8235294117647058
# rocaucs of fold 2: 0.8165554319614386
# accuracy of fold 3: 0.9117647058823529
# rocaucs of fold 3: 0.9272171099201132
# accuracy of fold 4: 0.8529411764705882
# rocaucs of fold 4: 0.9133751306165099
# accuracy of fold 5: 0.8529411764705882
# rocaucs of fold 5: 0.8407489803485355
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.8408668730650154
# avg_rocaucscore: 0.866133894061383
# avg_f1score: 0.7315699048426321
# avg_len: 7345.0
# accuracy of fold 1: 0.7894736842105263
# rocaucs of fold 1: 0.850828373015873
# accuracy of fold 2: 0.8235294117647058
# rocaucs of fold 2: 0.8165554319614386
# accuracy of fold 3: 0.9117647058823529
# rocaucs of fold 3: 0.9272171099201132
# accuracy of fold 4: 0.8529411764705882
# rocaucs of fold 4: 0.9133751306165099
# accuracy of fold 5: 0.8529411764705882
# rocaucs of fold 5: 0.8407489803485355
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.8461300309597523
# avg_rocaucscore: 0.8697450051724941
# avg_f1score: 0.7386810159537431
# avg_len: 7345.0
# accuracy of fold 1: 0.7894736842105263
# rocaucs of fold 1: 0.8510019841269841
# accuracy of fold 2: 0.8235294117647058
# rocaucs of fold 2: 0.8165554319614386
# accuracy of fold 3: 0.9117647058823529
# rocaucs of fold 3: 0.9272171099201132
# accuracy of fold 4: 0.8529411764705882
# rocaucs of fold 4: 0.9133751306165099
# accuracy of fold 5: 0.8529411764705882
# rocaucs of fold 5: 0.8407489803485355
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.8461300309597523
# avg_rocaucscore: 0.8697797273947163
# avg_f1score: 0.7387127619854892
# avg_len: 7345.0
# accuracy of fold 1: 0.7894736842105263
# rocaucs of fold 1: 0.8510019841269841
# accuracy of fold 2: 0.8823529411764706
# rocaucs of fold 2: 0.9104981966494757
# accuracy of fold 3: 0.9411764705882353
# rocaucs of fold 3: 0.9514106583072099
# accuracy of fold 4: 0.8823529411764706
# rocaucs of fold 4: 0.9376698014629049
# accuracy of fold 5: 0.9117647058823529
# rocaucs of fold 5: 0.9120655947685982
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.8814241486068111
# avg_rocaucscore: 0.9125292470630347
# avg_f1score: 0.8343050484868666
# avg_len: 919.0
# accuracy of fold 1: 0.7368421052631579
# rocaucs of fold 1: 0.8059863031233998
# accuracy of fold 2: 0.7647058823529411
# rocaucs of fold 2: 0.775440725385108
# accuracy of fold 3: 0.8529411764705882
# rocaucs of fold 3: 0.8559004955000507
# accuracy of fold 4: 0.8235294117647058
# rocaucs of fold 4: 0.8663531870428423
# accuracy of fold 5: 0.8235294117647058
# rocaucs of fold 5: 0.8164543095021404
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.8003095975232197
# avg_rocaucscore: 0.8240270041107081
# avg_f1score: 0.6393362697908153
# avg_len: 9180.4
# accuracy of fold 1: 0.5526315789473685
# rocaucs of fold 1: 0.693708717357911
# accuracy of fold 2: 0.7352941176470589
# rocaucs of fold 2: 0.7724592982101325
# accuracy of fold 3: 0.7941176470588235
# rocaucs of fold 3: 0.82862439747868
# accuracy of fold 4: 0.8235294117647058
# rocaucs of fold 4: 0.8602925809822363
# accuracy of fold 5: 0.6470588235294118
# rocaucs of fold 5: 0.734221525600836
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.7105263157894737
# avg_rocaucscore: 0.7778613039259591
# avg_f1score: 0.563764544427646
# avg_len: 139.2
# Path of read in data: ../datasets/GLIOMA.csv
# accuracy of fold 1: 0.6
# rocaucs of fold 1: 0.7477678571428572
# accuracy of fold 2: 0.8
# rocaucs of fold 2: 0.7976190476190477
# accuracy of fold 3: 0.8
# rocaucs of fold 3: 0.7976190476190477
# accuracy of fold 4: 0.8
# rocaucs of fold 4: 0.7976190476190477
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.6190476190476191
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.7
# avg_rocaucscore: 0.7519345238095239
# avg_f1score: 0.5604761904761905
# avg_len: 3547.0
# accuracy of fold 1: 0.6
# rocaucs of fold 1: 0.7477678571428572
# accuracy of fold 2: 0.8
# rocaucs of fold 2: 0.7976190476190477
# accuracy of fold 3: 0.8
# rocaucs of fold 3: 0.7976190476190477
# accuracy of fold 4: 0.7
# rocaucs of fold 4: 0.7380952380952381
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.6190476190476191
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.68
# avg_rocaucscore: 0.740029761904762
# avg_f1score: 0.5442857142857143
# avg_len: 3547.0
# accuracy of fold 1: 0.6
# rocaucs of fold 1: 0.7477678571428572
# accuracy of fold 2: 0.8
# rocaucs of fold 2: 0.7976190476190477
# accuracy of fold 3: 0.8
# rocaucs of fold 3: 0.7976190476190477
# accuracy of fold 4: 0.7
# rocaucs of fold 4: 0.7380952380952381
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.6190476190476191
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.68
# avg_rocaucscore: 0.740029761904762
# avg_f1score: 0.5442857142857143
# avg_len: 3547.0
# accuracy of fold 1: 0.6
# rocaucs of fold 1: 0.7433035714285714
# accuracy of fold 2: 0.6
# rocaucs of fold 2: 0.6785714285714286
# accuracy of fold 3: 0.8
# rocaucs of fold 3: 0.7976190476190477
# accuracy of fold 4: 0.6
# rocaucs of fold 4: 0.6785714285714286
# accuracy of fold 5: 0.7
# rocaucs of fold 5: 0.8214285714285714
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.6599999999999999
# avg_rocaucscore: 0.7438988095238095
# avg_f1score: 0.5460714285714285
# avg_len: 444.0
# accuracy of fold 1: 0.6
# rocaucs of fold 1: 0.7477678571428572
# accuracy of fold 2: 0.9
# rocaucs of fold 2: 0.8571428571428572
# accuracy of fold 3: 0.8
# rocaucs of fold 3: 0.7976190476190477
# accuracy of fold 4: 0.6
# rocaucs of fold 4: 0.6785714285714286
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.6190476190476191
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.6799999999999999
# avg_rocaucscore: 0.740029761904762
# avg_f1score: 0.5433333333333333
# avg_len: 4432.0
# accuracy of fold 1: 0.7
# rocaucs of fold 1: 0.828125
# accuracy of fold 2: 0.7
# rocaucs of fold 2: 0.7420634920634921
# accuracy of fold 3: 0.7
# rocaucs of fold 3: 0.7380952380952381
# accuracy of fold 4: 0.7
# rocaucs of fold 4: 0.7380952380952381
# accuracy of fold 5: 0.5
# rocaucs of fold 5: 0.7023809523809523
# --------Baseline2 filter PCA--------
# avg_acc_scikit: 0.6599999999999999
# avg_rocaucscore: 0.7497519841269842
# avg_f1score: 0.5805952380952382
# avg_len: 40.0
# Path of read in data: ../datasets/AllBooks_baseline_DTM_Labelled.csv
# accuracy of fold 1: 0.6885245901639344
# rocaucs of fold 1: 0.697901097665324
# accuracy of fold 2: 0.7264957264957265
# rocaucs of fold 2: 0.7363133167009668
# accuracy of fold 3: 0.7606837606837606
# rocaucs of fold 3: 0.7558376487249903
# accuracy of fold 4: 0.7350427350427351
# rocaucs of fold 4: 0.7439796162873423
# accuracy of fold 5: 0.7008547008547008
# rocaucs of fold 5: 0.708400040568367
# --------Baseline2 filter mi--------
# avg_acc_scikit: 0.7223203026481715
# avg_rocaucscore: 0.7284863439893982
# avg_f1score: 0.48419575557651406
# avg_len: 6612.0
# accuracy of fold 1: 0.6639344262295082
# rocaucs of fold 1: 0.686446420585647
# accuracy of fold 2: 0.717948717948718
# rocaucs of fold 2: 0.7339332857412144
# accuracy of fold 3: 0.7435897435897436
# rocaucs of fold 3: 0.7487602285247317
# accuracy of fold 4: 0.717948717948718
# rocaucs of fold 4: 0.7347865222645269
# accuracy of fold 5: 0.7008547008547008
# rocaucs of fold 5: 0.708400040568367
# --------Baseline2 filter chi2--------
# avg_acc_scikit: 0.7088552613142778
# avg_rocaucscore: 0.7224652995368974
# avg_f1score: 0.4751028534604135
# avg_len: 6612.0
# accuracy of fold 1: 0.6639344262295082
# rocaucs of fold 1: 0.686446420585647
# accuracy of fold 2: 0.717948717948718
# rocaucs of fold 2: 0.7339332857412144
# accuracy of fold 3: 0.7521367521367521
# rocaucs of fold 3: 0.7534576177652379
# accuracy of fold 4: 0.717948717948718
# rocaucs of fold 4: 0.7347865222645269
# accuracy of fold 5: 0.7008547008547008
# rocaucs of fold 5: 0.708400040568367
# --------Baseline2 filter anova--------
# avg_acc_scikit: 0.7105646630236795
# avg_rocaucscore: 0.7234047773849988
# avg_f1score: 0.4772206501591933
# avg_len: 6612.0
# accuracy of fold 1: 0.6065573770491803
# rocaucs of fold 1: 0.6760697683891418
# accuracy of fold 2: 0.6410256410256411
# rocaucs of fold 2: 0.6798323665526049
# accuracy of fold 3: 0.6239316239316239
# rocaucs of fold 3: 0.6648367462724865
# accuracy of fold 4: 0.5641025641025641
# rocaucs of fold 4: 0.6562253042791169
# accuracy of fold 5: 0.46153846153846156
# rocaucs of fold 5: 0.6164964013503291
# --------Baseline2 filter reliefF--------
# avg_acc_scikit: 0.5794311335294943
# avg_rocaucscore: 0.6586921173687357
# avg_f1score: 0.36085256848550595
# avg_len: 827.0
# accuracy of fold 1: 0.6557377049180327
# rocaucs of fold 1: 0.6794611264679999
# accuracy of fold 2: 0.7094017094017094
# rocaucs of fold 2: 0.7292358965007081
# accuracy of fold 3: 0.7521367521367521
# rocaucs of fold 3: 0.7534576177652379
# accuracy of fold 4: 0.717948717948718
# rocaucs of fold 4: 0.7347865222645269
# accuracy of fold 5: 0.7008547008547008
# rocaucs of fold 5: 0.708400040568367
# --------Baseline2 filter variance--------
# avg_acc_scikit: 0.7072159170519827
# avg_rocaucscore: 0.721068240713368
# avg_f1score: 0.47204054238115845
# avg_len: 7407.8
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38836\2095818497.py in <module>
#      71             #     print(AfterFeatureSelection)
#      72                 if(AfterFeatureSelection!=[]):
# ---> 73                     x_train, x_test, y_train, y_test = train_test_clean(training_Data[i], testing_Data[i], AfterFeatureSelection)
#      74                     SUM_OF_COLUMNS = SUM_OF_COLUMNS + int(len_of_columns)
#      75                     acc_scikit, rocaucs, f1score = train_model(x_train, x_test, y_train, y_test, classifier)
#
# ~\AppData\Local\Temp\ipykernel_38836\1557140528.py in train_test_clean(train_data, test_data, choosedFeature_AfterAction)
#       2     temp = train_data.copy()
#       3     del temp['class']
# ----> 4     temp_selected= temp[choosedFeature_AfterAction]
#       5     x_train = temp_selected.sort_index(axis=1)
#       6 #     print(x_train) #80筆資料
#
# C:\ProgramLanguage\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3809             if is_iterator(key):
#    3810                 key = list(key)
# -> 3811             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812
#    3813         # take() does not accept boolean indexers
#
# C:\ProgramLanguage\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    6111             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6112
# -> 6113         self._raise_if_missing(keyarr, indexer, axis_name)
#    6114
#    6115         keyarr = self.take(indexer)
#
# C:\ProgramLanguage\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6174
#    6175             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6176             raise KeyError(f"{not_found} not in index")
#    6177
#    6178     @overload
#
# KeyError: "['class'] not in index"

# %%
curt = datetime.now()
curt = str(curt.year)+str(curt.month)+str(curt.day)
with pd.ExcelWriter(f'./result_excel_filter/result_baseline_fs_{CLASSIFIER_STRING}_{curt}.xlsx') as writer:
    result_baseline.to_excel(writer, sheet_name='baseline_svm_fs')
