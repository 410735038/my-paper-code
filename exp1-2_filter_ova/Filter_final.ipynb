# %%
import os
import math
from numpy import * 
import pandas as pd
import time
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 若要測試單一個，請以以下方式引入單一資料集
# <span id="singleRunHead"></span>

# %%
# dir_data = '../datasets/'
# DATASET_CSV_NAME = '1_zoo.csv'
# DATASET_NAME = 'zoo'
# dir_train_test_data = f'../train_test_datasets/{DATASET_NAME}'
# train_data_loc = os.path.join(dir_data, DATASET_CSV_NAME)
# print('Path of read in data: %s' % (train_data_loc))
# data = pd.read_csv(train_data_loc)
# data.head()

# %%
# len(data.columns-2)

# %%
# train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
# train_1 = pd.read_csv(train_1_data_loc)
# train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
# train_2 = pd.read_csv(train_2_data_loc)
# train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
# train_3 = pd.read_csv(train_3_data_loc)
# train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
# train_4 = pd.read_csv(train_4_data_loc)
# train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
# train_5 = pd.read_csv(train_5_data_loc)
# test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
# test_1 = pd.read_csv(test_1_data_loc)
# test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
# test_2 = pd.read_csv(test_2_data_loc)
# test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
# test_3 = pd.read_csv(test_3_data_loc)
# test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
# test_4 = pd.read_csv(test_4_data_loc)
# test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
# test_5 = pd.read_csv(test_5_data_loc)
# del train_1['numbers']
# del train_2['numbers']
# del train_3['numbers']
# del train_4['numbers']
# del train_5['numbers']
# del test_1['numbers']
# del test_2['numbers']
# del test_3['numbers']
# del test_4['numbers']
# del test_5['numbers']
# training_Data = []
# training_Data.append(train_1)
# training_Data.append(train_2)
# training_Data.append(train_3)
# training_Data.append(train_4)
# training_Data.append(train_5)
# testing_Data = []
# testing_Data.append(test_1)
# testing_Data.append(test_2)
# testing_Data.append(test_3)
# testing_Data.append(test_4)
# testing_Data.append(test_5)
# training_Data[0]

# %% [markdown]
# ### Library

# %%
from sklearn.feature_selection import mutual_info_classif, VarianceThreshold
from sklearn.feature_selection import chi2, f_classif
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import SelectKBest
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score, roc_curve, auc, f1_score, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, MinMaxScaler
import matplotlib.pyplot as plt
from ReliefF import ReliefF
from sklearn.linear_model import LassoCV, RidgeCV, Ridge
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ### Classifier

# %%
svm = SVC(kernel='rbf', probability=True, decision_function_shape='ovr', random_state=42) ## classifier
knn = KNeighborsClassifier()
# svm = LinearSVC(multi_class='crammer_singer')

# %% [markdown]
# ### Datasets tags

# %%
DATASETS = [
#     'zoo',
    'Landsat',
    'soybean',
    'waveform',
    'Splice',
    'urban_land_cover',
    'SCADI', 
    'lung_discrete',
    'CNAE-9',
    'oh15',
    'lung',
    'TOX_171',
    'orlraws10P',
    'CLL_SUB_111',
    'CARCINOM',
    'GLIOMA',
    'AllBooks_baseline_DTM_Labelled'
]
    
DATASETS_CSV = [
#     '1_zoo',
    '2_Landsat',
    '3_soybean', 
    '4_waveform',
    '5_Splice',
    '6_urban_land_cover',
    '7_SCADI',
    '9_lung_discrete',
    '11_CNAE-9',
    '12_oh15',
    '13_lung',
    '14_TOX_171',
    '15_orlraws10P',
    '16_CLL_SUB_111',
    'CARCINOM',
    'GLIOMA',
    'AllBooks_baseline_DTM_Labelled'
]

# %% [markdown]
# ### Decomposition

# %% [markdown]
# #### OVA

# %%
'''
args:
    train_array: 訓練的資料，每個trainData要呼叫一次以執行 decomposition
return:
    data_temp: 進行decomposition後的資料集，會在最後加上 class_ova 的標籤
'''
def decomposition(train_array):
    class_ova = [] ## ova label 佔存，每次迴圈插入進當次的 ova dataframe
    data_temp = [] ## ova dataframe container，分別會有「是 i 與非 i 的 label」
    for i in range(data['class'].value_counts().size):
        data_temp.append(train_array.copy())
        class_ova = []
        for j in range(train_array["class"].size):
            if(data_temp[i]["class"][j] == i+1):
                class_ova.append(1)
            elif(data_temp[i]["class"][j] != i+1):
                class_ova.append(2)
        data_temp[i][str("class_ova_")+str(i+1)] = class_ova
    return data_temp

# %% [markdown]
# #### ovo

# %%
from itertools import combinations
def combination(n, k):
    if k > n:
        return 0
    else:
        combinations_list = list(combinations(range(1, n+1), k))
        
        for i in range(len(combinations_list)):
            combinations_list[i] = [eval(str(j)) for j in combinations_list[i]]
        
        return combinations_list
# result= combination(9, 2)
# print(result)
# print(len(result))

# %%
def decomposition_ovo(train_array):   
    c = combination(CLASS_AMOUNT, 2)
    ovo_container = []
    for i in range(len(c)):
        
        class_ova = []
        t = train_array.copy()
        tt1 = t.loc[train_array['class'] == c[i][0]]
        tt1 = tt1.reset_index(drop=True).astype('int')
        tt2 = t.loc[train_array['class'] == c[i][1]]
        tt2 = tt2.reset_index(drop=True).astype('int')
        for j in range(tt1['class'].size):
            if (tt1['class'][j] != 1 or tt1['class'][j] == 1):
                class_ova.append(1)
        for j in range(tt2['class'].size):
            if(tt2['class'][j] != 1):
                class_ova.append(2)
        tt3 = pd.concat([tt1, tt2]).reset_index(drop=True)
        tt3['class_ovo'] = class_ova
#     tt3
        ovo_container.append(tt3)
    return ovo_container, len(c)

# %% [markdown]
# ### Feature Selection Algos

# %% [markdown]
# ### Filter 六合一都在下面這一個 cell，其他有要個別跑可個別呼叫，但還是都須先執行

# %%
'''
MI,chi2,anova will use this
args:
    cols_container: 用來裝每次 fs 後篩選出來的 feature 們
    data_temp: 沒有特別意義，就是資料集
return:
    cols_container: 把 decomposition 後的資料集們個別進行 fs 後，篩出來的 f 裝在這個陣列內回傳
'''
def featureSelection(cols_container, data_temp, filter_algo):
    ## fs
# FILTER_ALGO=['mi','chi2','anova','reliefF','variance']
    
#     print("-------fs-------")
    if(filter_algo == 'reliefF'):
#         print("OVA reliefF")
        cols_container = fs_reliefF_ova(cols_container, data_temp)
    elif(filter_algo == 'PCA'):
#         print("OVA PCA")
        cols_container = fs_PCA_ova(cols_container, data_temp)
    else:
        if(filter_algo == 'mi'): 
#             print("OVA MI")
            selector = SelectPercentile(mutual_info_classif, percentile=80) ## fs- selector
        elif(filter_algo == 'chi2'):
#             print("OVA CHI2")
            selector = SelectPercentile(chi2, percentile=80) ## fs- selector
        elif(filter_algo == 'anova'): 
#             print("OVA ANOVA")
            selector = SelectPercentile(f_classif, percentile=80) ## fs- selector
        elif(filter_algo == 'variance'): 
#             print("OVA VARIANCE")
            selector = VarianceThreshold(threshold=(0.8-(1*0.8)))
        
        for i in range(data['class'].value_counts().size):
            data_ova = data_temp[i].copy()
            
            mms = pd.DataFrame(data=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1))
            data_ova_mxs = MinMaxScaler().fit_transform(mms)
            
            data_ova_mxs = pd.DataFrame(data=data_ova_mxs, columns=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1).columns)
            data_ova_mxs['class'] = data_ova['class']
            data_ova_mxs[str('class_ova_')+str(i+1)] = data_ova[str('class_ova_')+str(i+1)]

            del data_ova_mxs['class']  
            data_ova_no_label = data_ova_mxs.copy()
            del data_ova_no_label[str('class_ova_')+str(i+1)]
            '''---------'''
#             del data_ova['class']
#             data_ova_no_label = data_ova.copy()
#             del data_ova_no_label[str('class_ova_')+str(i+1)]
            
            try:
                x_reduced = selector.fit_transform(data_ova_no_label, data_ova[str('class_ova_')+str(i+1)])
            
                cols = selector.get_support(indices=True)
                selected_columns = data_ova_no_label.iloc[:,cols].columns.tolist()
                cols_container.append(selected_columns)
            except:
                cols_container.append([])
    return cols_container

# %%
'''
MI,chi2,anova will use this
'''
def featureSelection_ovo(cols_container, data_temp, looptimes, filter_algo):
    ## fs
#     print("-------fs-------")
    if(filter_algo == 'reliefF'):
#         print("OVO relefF")
        cols_container = fs_reliefF_ovo(cols_container, data_temp, looptimes)
    elif(filter_algo == 'PCA'):
#         print("OVO PCA")
        conls_container = fs_PCA_ovo(cols_container, data_temp, looptimes)
    else:
        if(filter_algo == 'mi'): 
#             print("OVO MI")
            selector = SelectPercentile(mutual_info_classif, percentile=80) ## fs- selector
        elif(filter_algo == 'chi2'):
#             print("OVO CHI2")
            selector = SelectPercentile(chi2, percentile=80) ## fs- selector
        elif(filter_algo == 'anova'):
#             print("OVO ANOVA")
            selector = SelectPercentile(f_classif, percentile=80) ## fs- selector
        elif(filter_algo == 'variance'): 
#             print("OVO VARIANCE")
            selector = VarianceThreshold(threshold=(0.8-(1*0.8)))

        for i in range(looptimes):
            data_ovo = data_temp[i].copy()

            mms = pd.DataFrame(data=data_ovo.drop(['class', 'class_ovo'], axis=1))
            data_ovo_mxs = MinMaxScaler().fit(mms).transform(mms) 
            
            data_ovo_mxs = pd.DataFrame(data=data_ovo_mxs, columns=data_ovo.drop(['class', 'class_ovo'], axis=1).columns)
            
            data_ovo_mxs['class'] = data_ovo['class']
            data_ovo_mxs['class_ovo'] = data_ovo['class_ovo']
            
            del data_ovo_mxs['class']
            data_ovo_no_label = data_ovo_mxs.copy()
            del data_ovo_no_label['class_ovo']
            '''---------'''
#             del data_ovo['class']
#             data_ovo_no_label = data_ovo.copy()
#             del data_ovo_no_label['class_ovo']
            
            try:
                x_reduced = selector.fit_transform(data_ovo_no_label, data_ovo['class_ovo'])
#             print(x_reduced.shape)
                cols = selector.get_support(indices=True)
                selected_columns = data_ovo_no_label.iloc[:,cols].columns.tolist()
                cols_container.append(selected_columns)
            except:
                cols_container.append([])
    return cols_container

# %%
def fs_PCA_ova(cols_container, data_temp):
#     print("-------fs-------")
    
    
    for i in range(data['class'].value_counts().size):
#         pca_components = min(len(list(data_temp[i]['class'])), len(data_temp[i].columns)-2)
        try:
#             print(f'pca ova loop{i}, situation 1')
            pca_components=math.ceil(float(len(list(data_temp[i].columns))-2)*0.8)
            n = pca_components
            pca = PCA(n_components=n)

            data_ova = data_temp[i].copy()

            mms = pd.DataFrame(data=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1))
            data_ova_mxs = MinMaxScaler().fit_transform(mms)

            data_ova_mxs = pd.DataFrame(data=data_ova_mxs, columns=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1).columns)
            data_ova_mxs['class'] = data_ova['class']
            data_ova_mxs[str('class_ova_')+str(i+1)] = data_ova[str('class_ova_')+str(i+1)]


            del data_ova_mxs['class']  
            data_ova_no_label = data_ova_mxs.copy()
            del data_ova_no_label[str('class_ova_')+str(i+1)]

            pca.fit(data_ova_no_label)
        except:
            print(f'pca ova loop{i}, situation 2')
            
            pca_components=min(len(list(data_temp[i]['class'])), len(data_temp[i].columns)-2)
            n = pca_components
            pca = PCA(n_components=n)

            data_ova = data_temp[i].copy()

            mms = pd.DataFrame(data=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1))
            data_ova_mxs = MinMaxScaler().fit_transform(mms)

            data_ova_mxs = pd.DataFrame(data=data_ova_mxs, columns=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1).columns)
            data_ova_mxs['class'] = data_ova['class']
            data_ova_mxs[str('class_ova_')+str(i+1)] = data_ova[str('class_ova_')+str(i+1)]


            del data_ova_mxs['class']  
            data_ova_no_label = data_ova_mxs.copy()
            del data_ova_no_label[str('class_ova_')+str(i+1)]

            pca.fit(data_ova_no_label)
        x_fit_train = pca.transform(data_ova_no_label)
        pca_data = shape(x_fit_train)
#         print(pca_data[1])
#         x_t_test = pca.transform(x_test)

        meanVals = mean(data_ova_no_label, axis=0)
        dataAdjust = data_ova_no_label - meanVals
        covMat = cov(dataAdjust, rowvar=0)
        eigVals, eigVects = linalg.eig(mat(covMat))
        eigVals =  eigVals.astype(float)
        
        eigVals_list=eigVals.tolist()
        feature_list = []
        feature_num=len(eigVals_list)
        for i in range(feature_num):
            feature_list.append(i)
#         print(feature_list)
        dict1 = dict(zip(feature_list, eigVals_list))
        a =  sorted(dict1.items(), key = lambda x: x[1], reverse=True)
        data_result_np=array(a)
#         print(data_result_np)
        data_feature_selection =data_result_np[:pca_data[1]]
#         print(data_feature_selection)
        
        data_list_divide = []
        for i in data_feature_selection:
            for j in i :
                data_list_divide.append(j)
        #print data_list_divide
        feature_list_result = []
        num = 0
        for f in data_list_divide:
            if (num != (int(pca_data[1]))*2):
                feature_list_result.append(int(data_list_divide[num]))  
                num = num + 2
            else:
                break
#         print ('feature_select_list :',feature_list_result)  #得知那些屬性被選擇了
        '''
        到這為止
        '''
        selected_columns = data_ova_no_label.iloc[:,feature_list_result].columns.tolist()
        cols_container.append(selected_columns)
        
    return cols_container

# %%
def fs_PCA_ovo(cols_container, data_temp, looptimes):
#     print("-------fs-------")
#     pca_components=math.ceil((len(list(data))-1)*0.5)
    
    
#     for i in range(data['class'].value_counts().size):
    for i in range(looptimes):
#         pca_components = min(len(list(data_temp[i]['class'])), len(data_temp[i].columns)-2)
        try:
#             print(f'pca ovo loop{i}, situation 1')
            
            pca_components=math.ceil(float(len(list(data_temp[i].columns))-2)*0.8)
            n = pca_components
            pca = PCA(n_components=n)

            data_ovo = data_temp[i].copy()

            mms = pd.DataFrame(data=data_ovo.drop(['class', 'class_ovo'], axis=1))
            data_ovo_mxs = MinMaxScaler().fit(mms).transform(mms) 

            data_ovo_mxs = pd.DataFrame(data=data_ovo_mxs, columns=data_ovo.drop(['class', 'class_ovo'], axis=1).columns)

            data_ovo_mxs['class'] = data_ovo['class']
            data_ovo_mxs['class_ovo'] = data_ovo['class_ovo']

            del data_ovo_mxs['class']
            data_ovo_no_label = data_ovo_mxs.copy()
            del data_ovo_no_label['class_ovo']

            pca.fit(data_ovo_no_label)
        except:
            print(f'pca ovo loop{i}, situation 2')

            pca_components = min(len(list(data_temp[i]['class'])), len(data_temp[i].columns)-2)
            n = pca_components
            pca = PCA(n_components=n)

            data_ovo = data_temp[i].copy()

            mms = pd.DataFrame(data=data_ovo.drop(['class', 'class_ovo'], axis=1))
            data_ovo_mxs = MinMaxScaler().fit(mms).transform(mms) 

            data_ovo_mxs = pd.DataFrame(data=data_ovo_mxs, columns=data_ovo.drop(['class', 'class_ovo'], axis=1).columns)

            data_ovo_mxs['class'] = data_ovo['class']
            data_ovo_mxs['class_ovo'] = data_ovo['class_ovo']

            del data_ovo_mxs['class']
            data_ovo_no_label = data_ovo_mxs.copy()
            del data_ovo_no_label['class_ovo']
            
            pca.fit(data_ovo_no_label)
            
        x_fit_train = pca.transform(data_ovo_no_label)
        pca_data = shape(x_fit_train)
#         print(pca_data[1])
#         x_t_test = pca.transform(x_test)

        meanVals = mean(data_ovo_no_label, axis=0)
        dataAdjust = data_ovo_no_label - meanVals
        covMat = cov(dataAdjust, rowvar=0)
        eigVals, eigVects = linalg.eig(mat(covMat))
        eigVals =  eigVals.astype(float)
        
        eigVals_list=eigVals.tolist()
        feature_list = []
        feature_num=len(eigVals_list)
        for k in range(feature_num):
            feature_list.append(k)
        dict1 = dict(zip(feature_list, eigVals_list))
        a =  sorted(dict1.items(), key = lambda x: x[1], reverse=True)
        data_result_np=array(a)
#         print(data_result_np)
        data_feature_selection =data_result_np[:pca_data[1]]
#         print(data_feature_selection)
        
        data_list_divide = []
        for l in data_feature_selection:
            for m in l :
                data_list_divide.append(m)
        #print data_list_divide
        feature_list_result = []
        num = 0
        for f in data_list_divide:
            if (num != (int(pca_data[1]))*2):
                feature_list_result.append(int(data_list_divide[num]))  
                num = num + 2
            else:
                break
#         print ('feature_select_list :',feature_list_result)  #得知那些屬性被選擇了
        '''
        到這為止
        '''
        selected_columns = data_ovo_no_label.iloc[:,feature_list_result].columns.tolist()
        cols_container.append(selected_columns)
        
    return cols_container

# %%
def fs_reliefF_ova(cols_container, data_temp):
     ## fs
#     print("-------fs-------")
    for i in range(data['class'].value_counts().size):
        data_ova = data_temp[i].copy()
        mms = pd.DataFrame(data=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1))
        data_ova_mxs = MinMaxScaler().fit_transform(mms)
        
        data_ova_mxs = pd.DataFrame(data=data_ova_mxs, columns=data_ova.drop(['class', str('class_ova_')+str(i+1)], axis=1).columns)
        data_ova_mxs['class'] = data_ova['class']
        data_ova_mxs[str('class_ova_')+str(i+1)] = data_ova[str('class_ova_')+str(i+1)]
        del data_ova_mxs['class']  
        data_ova_no_label = data_ova_mxs.copy()
        del data_ova_no_label[str('class_ova_')+str(i+1)]
        
        selector_reliefF = ReliefF(n_neighbors=1, n_features_to_keep=math.ceil((len(list(data))-2)*0.8))
        # fit_transform(x_train, y_train)
        
        d = data_ova_no_label.copy()
        d = d.values
        feat = asarray(d)
        label = asarray(data_ova[str('class_ova_')+str(i+1)])
        
        f = selector_reliefF.fit(feat, label)
#         print(f)
        feature_list_result = f[0:math.ceil((len(list(data))-1)*0.8)]
#         print(f[0:8])
        
        selected_columns = data_ova_no_label.iloc[:,feature_list_result].columns.tolist()
#         print(selected_columns)    
        cols_container.append(selected_columns)
#         print(i+1,'not ', i+1, ':',selected_columns)
    return cols_container

# %%
def fs_reliefF_ovo(cols_container, data_temp, looptimes):
    for i in range(looptimes):
        data_ovo = data_temp[i].copy()
        mms = pd.DataFrame(data=data_ovo.drop(['class', 'class_ovo'], axis=1))
        data_ovo_mxs = MinMaxScaler().fit(mms).transform(mms) 
        
        data_ovo_mxs = pd.DataFrame(data=data_ovo_mxs, columns=data_ovo.drop(['class', 'class_ovo'], axis=1).columns)
        
        data_ovo_mxs['class'] = data_ovo['class']
        data_ovo_mxs['class_ovo'] = data_ovo['class_ovo']
        
        del data_ovo_mxs['class']
        data_ovo_no_label = data_ovo_mxs.copy()
        del data_ovo_no_label['class_ovo']
        
        selector_reliefF = ReliefF(n_neighbors=1, n_features_to_keep=math.ceil((len(list(data))-1)*0.8))
        d = data_ovo_no_label.copy()
        d = d.values
        feat = asarray(d)
        label = asarray(data_ovo[str('class_ovo')])
        
        f = selector_reliefF.fit(feat, label)
#         print(f)
        feature_list_result = f[0:math.ceil((len(list(data))-1)*0.8)]
#         print(f[0:8])
        
        selected_columns = data_ovo_no_label.iloc[:,feature_list_result].columns.tolist()
#         print(selected_columns)    
        cols_container.append(selected_columns)
    return cols_container

# %% [markdown]
# ### Union and Intersection

# %%
'''
args:
    cols_container: fs 後的 f 集合，將每個 decomposition 後的 f 集合進行聯集
return:
    list(C): 把聯集後的結果回傳
'''
def Union(cols_container):
#     fs - Union
#     print("-------fs-Union-------")
    union_temp = cols_container.copy()
#     print(len(cols_container))
    A = set(union_temp[0]) # 1
    B = set(union_temp[1]) # 2
    C = A.union(B)
    for i in range(2, len(union_temp)):
        A = set(union_temp[i])
        C = A.union(C)
#     print(C)
#     print('length of union set' + str(len(C)))
#     print(f'length of union set: {len(C)}')
    return list(C), len(C)

# %%
'''
args:
    cols_container: fs 後的 f 集合，將每個 decomposition 後的 f 集合進行交集
return:
    list(C): 把交集後的結果回傳
'''
def Intersection(cols_container):
    ## fs - intersection
#     print("-------fs-intersection-------")
    intersection_temp = cols_container.copy()
    A = set(intersection_temp[0]) # 1
    B = set(intersection_temp[1]) # 2
    C = A.intersection(B)
    for i in range(2, len(intersection_temp)):
        A = set(intersection_temp[i])
        C = A.intersection(C)
#     print(C)
#     print(f'length of intersection set: {len(C)}')
    return list(C), len(C)

# %% [markdown]
# ### train model

# %%
def train_test_clean(train_data, test_data, choosedFeature_AfterAction):
    temp = train_data.copy()
    del temp['class']
    temp_selected= temp[choosedFeature_AfterAction]
    x_train = temp_selected.sort_index(axis=1)
#     print(x_train) #80筆資料

    #把測試集手動取出與訓練集相同維度的所有資料
    temp_test = test_data.copy() #x_test
    del temp_test['class']
    temp_test_selected = temp_test[choosedFeature_AfterAction]
    x_test = temp_test_selected.sort_index(axis=1)
#     print(x_test)

    y_train = train_data['class']
    y_test = test_data['class']
    
    return x_train, x_test, y_train, y_test
def train_model(x_train, x_test, y_train, y_test, classifier):
    ## train model
#     print(x_train)
    classifier.fit(x_train, y_train)
    predicted = classifier.predict(x_test) # 預測的答案
    
#     print(predicted)
    '''-------------'''
#     predict_proba = classifier.predict_proba(x_test)
#     predict_proba = OneHotEncoder().fit_transform(predicted.reshape(-1,1)).toarray()
#     predict_proba = list(predict_proba)

#     not_predicted = []
#     for i in range(len(arange(1,7))):
#         if(i+1 not in predicted):
#             not_predicted.append(i+1)
# #     print(not_predicted)
#     if(not_predicted):
#         for i in range(len(not_predicted)):
#             for j in range(len(predict_proba)):
#                 predict_proba[j] = insert(predict_proba[j], not_predicted[i]-1, 0.)
#     print(predict_proba)
    '''-------------'''

    '''-------------'''
    lb = LabelBinarizer().fit(y_test)
    y_test_ = lb.transform(y_test)
    predict_proba = lb.transform(predicted)
    '''-------------'''

    y_test = array(list(y_test))
    predicted = array(list(predicted))
    y_train = array(list(y_train))
    
    # accuracy_train = svm.score(x_train, y_train) #x_train, y_train
    # print(accuracy_train)
#     rocaucscore = roc_auc_score(y_test_, predict_proba, multi_class='ovo',labels=arange(1,7), average='macro')
    rocaucscore = roc_auc_score(y_test_, predict_proba, average='macro')

    
    acc_scikit = accuracy_score(y_test, predicted)
#     accuracy_test = classifier.score(x_test, y_test) #x_test, y_test
    f1score = f1_score(y_test, predicted, average='macro')

    return acc_scikit, rocaucscore, f1score

def train_test_baseline(train_data, test_data):
    temp = train_data.copy()
    del temp['class']
    x_train = temp
    
    temp_test = test_data.copy()
    del temp_test['class']
    x_test = temp_test
    
    y_train = train_data['class']
    y_test = test_data['class']
    
    return x_train, x_test, y_train, y_test

# %% [markdown]
# ### 以下方式為跑結果，分為統整跑(一次跑全部)跟個別跑(跑單一資料集的單一演算法)

# %% [markdown]
# ### 1. 單一個別跑請參照以下，用途是作為確認程式碼是否OK時使用
# [並請確認有引入單一資料集->點我回上面](#singleRunHead)

# %%
accuracy_container = []
rocauc_container = []
f1score_container = []
acc_scikit_con = []
SUM_OF_COLUMNS = 0
for i in range(5):
    AfterFeatureSelection, len_of_columns = featureSelection(training_Data[i])
    x_train, x_test, y_train, y_test = train_test_clean(training_Data[i], testing_Data[i], AfterFeatureSelection)
    SUM_OF_COLUMNS = SUM_OF_COLUMNS + len_of_columns
    acc_scikit, rocaucs, f1score = train_model(x_train, x_test, y_train, y_test, classifier)
    # print(accuracy_U)
    acc_scikit_con.append(acc_scikit)
#     accuracy_container.append(accuracy)
    rocauc_container.append(rocaucs)
    f1score_container.append(f1score)
    print(f'accuracy of fold {i+1}: {acc_scikit}')
    print(f'rocaucs of fold {i+1}: {rocaucs}')
avg_acc_scikit = sum(acc_scikit_con)/5
# avg_acc = sum(accuracy_container)/5
avg_rocauc = sum(rocauc_container)/5
avg_f1score = sum(f1score_container)/5
print('--------Baseline2 MI--------')
# print(f'avg_acc: {avg_acc}')
print(f'avg_acc_scikit: {avg_acc_scikit}')
print(f'avg_rocaucscore: {avg_rocauc}')
print(f'avg_f1score: {avg_f1score}')
print(f'avg_len: {SUM_OF_COLUMNS/5}')

# %% [markdown]
# ### 2. 統整跑需要先做讀寫檔案操作

# %%
def writeFiles_Decom_UorI(STORE_PATH, DECOMPOSITION_TYPE, UorI, foldTurn, choosedFeature, f_len,FS_METHOD):
    try:
        file_U = open(STORE_PATH + f'/{DECOMPOSITION_TYPE}/{UorI}/{FS_METHOD}_folds{foldTurn+1}.txt','w')
    except:
        os.makedirs(STORE_PATH + f'/{DECOMPOSITION_TYPE}/{UorI}')
        file_U = open(STORE_PATH + f'/{DECOMPOSITION_TYPE}/{UorI}/{FS_METHOD}_folds{foldTurn+1}.txt','w')
    choosedFeature = sorted(choosedFeature)
    for item in choosedFeature:
        file_U.write(item+"\n")
    file_U.write(str(f_len)+"\n")
    file_U.close()

# %%
def readLines_UorI(STORE_PATH, DECOMPOSITION_TYPE, UorI, foldTurn,FS_METHOD):
    try:
        file1 = open(STORE_PATH + f'{DECOMPOSITION_TYPE}/{UorI}/{FS_METHOD}_folds{foldTurn+1}.txt', 'r')
        Lines = file1.readlines()
        choosedFeature = []
        for line in Lines:
            choosedFeature.append(line.strip())
        choosedFeature = choosedFeature[:-1]
        fs_len = Lines[-1]
        file1.close()
        return choosedFeature, fs_len
    except:
        return [], 0

# %%
result_ova = pd.DataFrame(columns=['datasetName', 'algoName','acc_u', 'acc_i', 'auc_u', 'auc_i', 'f1_u', 'f1_i', 'len_u', 'len_i','spend_time','reductionRate'])
result_ovo = pd.DataFrame(columns=['datasetName', 'algoName','acc_u', 'acc_i', 'auc_u', 'auc_i', 'f1_u', 'f1_i', 'len_u', 'len_i','spend_time','reductionRate'])

# %% [markdown]
# ### Filter 統整跑

# %%
CLASSIFIER_STRING = "KNN"
classifier = knn
FILTER_ALGO=['mi','chi2', 'anova','reliefF','variance', 'PCA']
curt = datetime.now()
curt = str(curt.year)+str(curt.month)+str(curt.day)
# FILTER_ALGO=['chi2']

dir_data = '../datasets/'
for qq in range(len(DATASETS)):
    DATASET_CSV_NAME = f'{DATASETS_CSV[qq]}.csv'
    DATASET_NAME = f'{DATASETS[qq]}'
    dir_train_test_data = f'../train_test_datasets/{DATASET_NAME}'

    train_data_loc = os.path.join(dir_data, DATASET_CSV_NAME)
    print('Path of read in data: %s' % (train_data_loc))
    data = pd.read_csv(train_data_loc)
    # data
    

    CLASS_AMOUNT = data['class'].value_counts().size
    FEATURE_AMOUNT = len(data.columns)-2
    # CLASS_AMOUNT

    train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
    train_1 = pd.read_csv(train_1_data_loc)
    train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
    train_2 = pd.read_csv(train_2_data_loc)
    train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
    train_3 = pd.read_csv(train_3_data_loc)
    train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
    train_4 = pd.read_csv(train_4_data_loc)
    train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
    train_5 = pd.read_csv(train_5_data_loc)
    test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
    test_1 = pd.read_csv(test_1_data_loc)
    test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
    test_2 = pd.read_csv(test_2_data_loc)
    test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
    test_3 = pd.read_csv(test_3_data_loc)
    test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
    test_4 = pd.read_csv(test_4_data_loc)
    test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
    test_5 = pd.read_csv(test_5_data_loc)
    del train_1['numbers']
    del train_2['numbers']
    del train_3['numbers']
    del train_4['numbers']
    del train_5['numbers']
    del test_1['numbers']
    del test_2['numbers']
    del test_3['numbers']
    del test_4['numbers']
    del test_5['numbers']
    training_Data = []
    training_Data.append(train_1)
    training_Data.append(train_2)
    training_Data.append(train_3)
    training_Data.append(train_4)
    training_Data.append(train_5)
    testing_Data = []
    testing_Data.append(test_1)
    testing_Data.append(test_2)
    testing_Data.append(test_3)
    testing_Data.append(test_4)
    testing_Data.append(test_5)
    
    spend_time_OVA_container = []
    spend_time_OVO_container = []
    
    for zz in range(len(FILTER_ALGO)):
        spend_time_OVA = 0
        spend_time_OVO = 0
        STORE_PATH = f'./{FILTER_ALGO[zz]}_FILTER_v4_percent80_{curt}/{DATASET_NAME}/'
        for i in range(5):
            cols_container_OVA = []
            cols_container_OVO = []

            # ova
            start_time_OVA = time.time()
            data_AfterDecomposition_OVA = decomposition(training_Data[i])
            cols_container_AfterFeatureSelection_OVA = featureSelection(cols_container_OVA, data_AfterDecomposition_OVA, FILTER_ALGO[zz])
            end_time_OVA = time.time()
            spend_time_OVA += end_time_OVA - start_time_OVA
            # ovo
            start_time_OVO = time.time()
            data_AfterDecomposition_OVO, looptimes = decomposition_ovo(training_Data[i])
            cols_container_AfterFeatureSelection_OVO = featureSelection_ovo(cols_container_OVO, data_AfterDecomposition_OVO, looptimes, FILTER_ALGO[zz])
            end_time_OVO = time.time()
            spend_time_OVO += end_time_OVO - start_time_OVO

            choosedFeature_AfterUnion_U_OVA, len_union_OVA = Union(cols_container_AfterFeatureSelection_OVA)
            choosedFeature_AfterUnion_U_OVO, len_union_OVO = Union(cols_container_AfterFeatureSelection_OVO)
            
            if(choosedFeature_AfterUnion_U_OVA != []):
                writeFiles_Decom_UorI(STORE_PATH, 'OVA', 'U', i, choosedFeature_AfterUnion_U_OVA, len_union_OVA, FILTER_ALGO[zz])
            if(choosedFeature_AfterUnion_U_OVO != []):
                writeFiles_Decom_UorI(STORE_PATH, 'OVO', 'U', i, choosedFeature_AfterUnion_U_OVO, len_union_OVO, FILTER_ALGO[zz])

            choosedFeature_AfterUnion_I_OVA, len_intersection_OVA = Intersection(cols_container_AfterFeatureSelection_OVA)
            choosedFeature_AfterUnion_I_OVO, len_intersection_OVO = Intersection(cols_container_AfterFeatureSelection_OVO)

            if(choosedFeature_AfterUnion_I_OVA != []):
                writeFiles_Decom_UorI(STORE_PATH, 'OVA', 'I', i, choosedFeature_AfterUnion_I_OVA, len_intersection_OVA, FILTER_ALGO[zz])
            if(choosedFeature_AfterUnion_I_OVO != []):
                writeFiles_Decom_UorI(STORE_PATH, 'OVO', 'I', i, choosedFeature_AfterUnion_I_OVO, len_intersection_OVO, FILTER_ALGO[zz])  
        spend_time_OVA = spend_time_OVA//5
        spend_time_OVO = spend_time_OVO//5
        spend_time_OVA_container.append(spend_time_OVA)
        spend_time_OVO_container.append(spend_time_OVO)
        
#     '''---------------------------------------------------------------------------------------------------------------'''            

#     TYPES = ['OVA', 'OVO']
#     print(DATASET_NAME)
#     for kk in range(len(FILTER_ALGO)):
#         STORE_PATH = f'./{FILTER_ALGO[kk]}_FILTER_v2/{DATASET_NAME}/'
#         for k in TYPES:
#             accuracy_container_U = []
#             accuracy_container_I = []
#             rocaucscore_U = []
#             rocaucscore_I = []
#             f1_scoreContainer_U = []
#             f1_scoreContainer_I = []
#             SUM_OF_U = 0
#             SUM_OF_I = 0
#             for i in range(5):
#                 choosedFeature_AfterUnion_U, len_union = readLines_UorI(STORE_PATH, k, 'U', i, FILTER_ALGO[kk])
#                 if(choosedFeature_AfterUnion_U != []):
#                     SUM_OF_U = SUM_OF_U + int(len_union)
#                     x_train_U, x_test_U, y_train_U, y_test_U = train_test_clean(training_Data[i], testing_Data[i], choosedFeature_AfterUnion_U)
#                     accuracy_U,  rocaucs_U, f1score_U = train_model(x_train_U, x_test_U, y_train_U, y_test_U, classifier)
#                     accuracy_container_U.append(accuracy_U)
#                     rocaucscore_U.append(rocaucs_U)
#                     f1_scoreContainer_U.append(f1score_U)
#                 else:
#                     accuracy_container_U.append(0)
#                     rocaucscore_U.append(0)
#                     f1_scoreContainer_U.append(0)
                    
#                 choosedFeature_AfterUnion_I, len_intersection = readLines_UorI(STORE_PATH, k, 'I', i, FILTER_ALGO[kk])
#                 if(choosedFeature_AfterUnion_I != []):
#                     SUM_OF_I = SUM_OF_I + int(len_intersection)

#                     x_train_I, x_test_I, y_train_I, y_test_I = train_test_clean(training_Data[i], testing_Data[i], choosedFeature_AfterUnion_I)
#                     accuracy_I, rocaucs_I, f1score_I = train_model(x_train_I, x_test_I, y_train_I, y_test_I, classifier)
#                     accuracy_container_I.append(accuracy_I)
#                     rocaucscore_I.append(rocaucs_I)
#                     f1_scoreContainer_I.append(f1score_I)    
#                 else:
#                     accuracy_container_I.append(0)
#                     rocaucscore_I.append(0)
#                     f1_scoreContainer_I.append(0)
                    
#             avg_acc_U = round(sum(accuracy_container_U)/5,3)
#             avg_rocaucscore_U = round(sum(rocaucscore_U)/5,3)
#             avg_f1score_U = round(sum(f1_scoreContainer_U)/5,3)

#             avg_acc_I = round(sum(accuracy_container_I)/5,3)
#             avg_rocaucscore_I = round(sum(rocaucscore_I)/5,3)
#             avg_f1score_I = round(sum(f1_scoreContainer_I)/5,3)

#             print(f'-----------{FILTER_ALGO[kk]},{k}----------')
#             print(f'U:avg_acc: {avg_acc_U}')
#             print(f'U:avg_rocaucscore: {avg_rocaucscore_U}')
#             print(f'U:avg_f1score: {avg_f1score_U}')
#             print(f'U:avg_union_len: {SUM_OF_U/5}')
#             print(f'I:avg_acc: {avg_acc_I}')
#             print(f'I:avg_rocaucscore: {avg_rocaucscore_I}')
#             print(f'I:avg_f1score: {avg_f1score_I}')
#             print(f'I:avg_intersection_len: {SUM_OF_I/5}')
            
#             if(k == 'OVA'):
#                 spend_time = spend_time_OVA_container[kk]
#                 reductionRate = round((SUM_OF_U/5)/FEATURE_AMOUNT, 3)
#             elif(k == 'OVO'):
#                 spend_time = spend_time_OVO_container[kk]
#                 reductionRate = round((SUM_OF_I/5)/FEATURE_AMOUNT, 3)
                
#             t = pd.DataFrame([{'datasetName':DATASET_NAME,
#                          'algoName':FILTER_ALGO[kk],
#                          'acc_u':str(avg_acc_U),
#                          'acc_i':str(avg_acc_I),
#                          'auc_u':str(avg_rocaucscore_U),
#                          'auc_i':str(avg_rocaucscore_I),
#                          'f1_u':str(avg_f1score_U),
#                          'f1_i':str(avg_f1score_I),
#                          'len_u':str(math.ceil(SUM_OF_U/5)),
#                          'len_i':str(math.ceil(SUM_OF_I/5)),
#                          'spend_time':str(round(spend_time,3)),
#                          'reductionRate':str(reductionRate)
#                         }])
#             if k == 'OVA':
#                 result_ova = pd.concat([result_ova, t]).reset_index(drop=True).astype('string')
#             elif k == 'OVO':
#                 result_ovo = pd.concat([result_ovo, t]).reset_index(drop=True).astype('string')
    
# with pd.ExcelWriter(f'./result_excel_filter/result_notbaseline_filter_{CLASSIFIER_STRING}_bigsets.xlsx') as writer:
#     result_ova.to_excel(writer, sheet_name='ova_svm')
#     result_ovo.to_excel(writer, sheet_name='ovo_svm')
# Out:
# Path of read in data: ../datasets/15_orlraws10P.csv
# pca ova loop0, situation 1
# pca ova loop0, situation 2
# pca ova loop1, situation 1
# pca ova loop1, situation 2
# pca ova loop2, situation 1
# pca ova loop2, situation 2
# pca
FILTER_ALGO=['mi','chi2', 'anova','reliefF','variance', 'PCA']
# FILTER_ALGO=['chi2']

dir_data = '../datasets/'
for qq in range(len(DATASETS)):
    DATASET_CSV_NAME = f'{DATASETS_CSV[qq]}.csv'
    DATASET_NAME = f'{DATASETS[qq]}'
    dir_train_test_data = f'../train_test_datasets/{DATASET_NAME}'

    train_data_loc = os.path.join(dir_data, DATASET_CSV_NAME)
    print('Path of read in data: %s' % (train_data_loc))
    data = pd.read_csv(train_data_loc)
    # data
    

    CLASS_AMOUNT = data['class'].value_counts().size
    FEATURE_AMOUNT = len(data.columns)-2
    # CLASS_AMOUNT

    train_1_data_loc = os.path.join(dir_train_test_data, 'train_1.csv')
    train_1 = pd.read_csv(train_1_data_loc)
    train_2_data_loc = os.path.join(dir_train_test_data, 'train_2.csv')
    train_2 = pd.read_csv(train_2_data_loc)
    train_3_data_loc = os.path.join(dir_train_test_data, 'train_3.csv')
    train_3 = pd.read_csv(train_3_data_loc)
    train_4_data_loc = os.path.join(dir_train_test_data, 'train_4.csv')
    train_4 = pd.read_csv(train_4_data_loc)
    train_5_data_loc = os.path.join(dir_train_test_data, 'train_5.csv')
    train_5 = pd.read_csv(train_5_data_loc)
    test_1_data_loc = os.path.join(dir_train_test_data, 'test_1.csv')
    test_1 = pd.read_csv(test_1_data_loc)
    test_2_data_loc = os.path.join(dir_train_test_data, 'test_2.csv')
    test_2 = pd.read_csv(test_2_data_loc)
    test_3_data_loc = os.path.join(dir_train_test_data, 'test_3.csv')
    test_3 = pd.read_csv(test_3_data_loc)
    test_4_data_loc = os.path.join(dir_train_test_data, 'test_4.csv')
    test_4 = pd.read_csv(test_4_data_loc)
    test_5_data_loc = os.path.join(dir_train_test_data, 'test_5.csv')
    test_5 = pd.read_csv(test_5_data_loc)
    del train_1['numbers']
    del train_2['numbers']
    del train_3['numbers']
    del train_4['numbers']
    del train_5['numbers']
    del test_1['numbers']
    del test_2['numbers']
    del test_3['numbers']
    del test_4['numbers']
    del test_5['numbers']
    training_Data = []
    training_Data.append(train_1)
    training_Data.append(train_2)
    training_Data.append(train_3)
    training_Data.append(train_4)
    training_Data.append(train_5)
    testing_Data = []
    testing_Data.append(test_1)
    testing_Data.append(test_2)
    testing_Data.append(test_3)
    testing_Data.append(test_4)
    testing_Data.append(test_5)
    
    TYPES = ['OVA', 'OVO']
    print(DATASET_NAME)
    for kk in range(len(FILTER_ALGO)):
        STORE_PATH = f'./{FILTER_ALGO[kk]}_FILTER_v4_percent80_2023101/{DATASET_NAME}/'
#         STORE_PATH = f'./{FILTER_ALGO[kk]}_FILTER_v4_percent80_{curt}/{DATASET_NAME}/'
        for k in TYPES:
            accuracy_container_U = []
            accuracy_container_I = []
            rocaucscore_U = []
            rocaucscore_I = []
            f1_scoreContainer_U = []
            f1_scoreContainer_I = []
            SUM_OF_U = 0
            SUM_OF_I = 0
            for i in range(5):
                choosedFeature_AfterUnion_U, len_union = readLines_UorI(STORE_PATH, k, 'U', i, FILTER_ALGO[kk])
                if(choosedFeature_AfterUnion_U != []):
                    SUM_OF_U = SUM_OF_U + int(len_union)
                    x_train_U, x_test_U, y_train_U, y_test_U = train_test_clean(training_Data[i], testing_Data[i], choosedFeature_AfterUnion_U)
                    accuracy_U,  rocaucs_U, f1score_U = train_model(x_train_U, x_test_U, y_train_U, y_test_U, classifier)
                    accuracy_container_U.append(accuracy_U)
                    rocaucscore_U.append(rocaucs_U)
                    f1_scoreContainer_U.append(f1score_U)
                else:
                    accuracy_container_U.append(0)
                    rocaucscore_U.append(0)
                    f1_scoreContainer_U.append(0)
                    
                choosedFeature_AfterUnion_I, len_intersection = readLines_UorI(STORE_PATH, k, 'I', i, FILTER_ALGO[kk])
                if(choosedFeature_AfterUnion_I != []):
                    SUM_OF_I = SUM_OF_I + int(len_intersection)

                    x_train_I, x_test_I, y_train_I, y_test_I = train_test_clean(training_Data[i], testing_Data[i], choosedFeature_AfterUnion_I)
                    accuracy_I, rocaucs_I, f1score_I = train_model(x_train_I, x_test_I, y_train_I, y_test_I, classifier)
                    accuracy_container_I.append(accuracy_I)
                    rocaucscore_I.append(rocaucs_I)
                    f1_scoreContainer_I.append(f1score_I)    
                else:
                    accuracy_container_I.append(0)
                    rocaucscore_I.append(0)
                    f1_scoreContainer_I.append(0)
                    
            avg_acc_U = round(sum(accuracy_container_U)/5,3)
            avg_rocaucscore_U = round(sum(rocaucscore_U)/5,3)
            avg_f1score_U = round(sum(f1_scoreContainer_U)/5,3)

            avg_acc_I = round(sum(accuracy_container_I)/5,3)
            avg_rocaucscore_I = round(sum(rocaucscore_I)/5,3)
            avg_f1score_I = round(sum(f1_scoreContainer_I)/5,3)

            print(f'-----------{FILTER_ALGO[kk]},{k}----------')
            print(f'U:avg_acc: {avg_acc_U}')
            print(f'U:avg_rocaucscore: {avg_rocaucscore_U}')
            print(f'U:avg_f1score: {avg_f1score_U}')
            print(f'U:avg_union_len: {SUM_OF_U/5}')
            print(f'I:avg_acc: {avg_acc_I}')
            print(f'I:avg_rocaucscore: {avg_rocaucscore_I}')
            print(f'I:avg_f1score: {avg_f1score_I}')
            print(f'I:avg_intersection_len: {SUM_OF_I/5}')
            
            if(k == 'OVA'):
#                 spend_time = spend_time_OVA_container[kk]
                reductionRate = round((SUM_OF_U/5)/FEATURE_AMOUNT, 3)
            elif(k == 'OVO'):
#                 spend_time = spend_time_OVO_container[kk]
                reductionRate = round((SUM_OF_I/5)/FEATURE_AMOUNT, 3)
                
            t = pd.DataFrame([{'datasetName':DATASET_NAME,
                         'algoName':FILTER_ALGO[kk],
                         'acc_u':str(avg_acc_U),
                         'acc_i':str(avg_acc_I),
                         'auc_u':str(avg_rocaucscore_U),
                         'auc_i':str(avg_rocaucscore_I),
                         'f1_u':str(avg_f1score_U),
                         'f1_i':str(avg_f1score_I),
                         'len_u':str(math.ceil(SUM_OF_U/5)),
                         'len_i':str(math.ceil(SUM_OF_I/5)),
                         'spend_time':str(round(0,3)),
                         'reductionRate':str(reductionRate)
                        }])
            if k == 'OVA':
                result_ova = pd.concat([result_ova, t]).reset_index(drop=True).astype('string')
            elif k == 'OVO':
                result_ovo = pd.concat([result_ovo, t]).reset_index(drop=True).astype('string')
# Out:
# Path of read in data: ../datasets/2_Landsat.csv
# Landsat
# -----------mi,OVA----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.855
# I:avg_rocaucscore: 0.883
# I:avg_f1score: 0.802
# I:avg_intersection_len: 13.2
# -----------mi,OVO----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.587
# I:avg_rocaucscore: 0.701
# I:avg_f1score: 0.461
# I:avg_intersection_len: 4.0
# -----------chi2,OVA----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.913
# I:avg_rocaucscore: 0.941
# I:avg_f1score: 0.898
# I:avg_intersection_len: 17.2
# -----------chi2,OVO----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.562
# I:avg_rocaucscore: 0.669
# I:avg_f1score: 0.391
# I:avg_intersection_len: 4.2
# -----------anova,OVA----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.868
# I:avg_rocaucscore: 0.894
# I:avg_f1score: 0.818
# I:avg_intersection_len: 16.2
# -----------anova,OVO----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.512
# I:avg_rocaucscore: 0.647
# I:avg_f1score: 0.372
# I:avg_intersection_len: 4.2
# -----------reliefF,OVA----------
# U:avg_acc: 0.961
# U:avg_rocaucscore: 0.975
# U:avg_f1score: 0.956
# U:avg_union_len: 28.4
# I:avg_acc: 0.967
# I:avg_rocaucscore: 0.978
# I:avg_f1score: 0.963
# I:avg_intersection_len: 27.6
# -----------reliefF,OVO----------
# U:avg_acc: 0.967
# U:avg_rocaucscore: 0.979
# U:avg_f1score: 0.962
# U:avg_union_len: 33.0
# I:avg_acc: 0.888
# I:avg_rocaucscore: 0.925
# I:avg_f1score: 0.86
# I:avg_intersection_len: 17.6
# -----------variance,OVA----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.869
# I:avg_rocaucscore: 0.917
# I:avg_f1score: 0.844
# I:avg_intersection_len: 34.0
# -----------variance,OVO----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.917
# U:avg_f1score: 0.844
# U:avg_union_len: 34.0
# I:avg_acc: 0.687
# I:avg_rocaucscore: 0.799
# I:avg_f1score: 0.646
# I:avg_intersection_len: 12.8
# -----------PCA,OVA----------
# U:avg_acc: 0.868
# U:avg_rocaucscore: 0.911
# U:avg_f1score: 0.84
# U:avg_union_len: 28.0
# I:avg_acc: 0.868
# I:avg_rocaucscore: 0.911
# I:avg_f1score: 0.84
# I:avg_intersection_len: 28.0
# -----------PCA,OVO----------
# U:avg_acc: 0.964
# U:avg_rocaucscore: 0.978
# U:avg_f1score: 0.959
# U:avg_union_len: 32.6
# I:avg_acc: 0.93
# I:avg_rocaucscore: 0.949
# I:avg_f1score: 0.916
# I:avg_intersection_len: 19.2
# Path of read in data: ../datasets/3_soybean.csv
# soybean
# -----------mi,OVA----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.726
# I:avg_rocaucscore: 0.885
# I:avg_f1score: 0.76
# I:avg_intersection_len: 8.0
# -----------mi,OVO----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.048
# I:avg_rocaucscore: 0.216
# I:avg_f1score: 0.032
# I:avg_intersection_len: 0.6
# -----------chi2,OVA----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.677
# I:avg_rocaucscore: 0.86
# I:avg_f1score: 0.706
# I:avg_intersection_len: 10.6
# -----------chi2,OVO----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.647
# I:avg_rocaucscore: 0.78
# I:avg_f1score: 0.55
# I:avg_intersection_len: 6.4
# -----------anova,OVA----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.69
# I:avg_rocaucscore: 0.882
# I:avg_f1score: 0.761
# I:avg_intersection_len: 9.0
# -----------anova,OVO----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.679
# I:avg_rocaucscore: 0.789
# I:avg_f1score: 0.573
# I:avg_intersection_len: 6.0
# -----------reliefF,OVA----------
# U:avg_acc: 0.879
# U:avg_rocaucscore: 0.962
# U:avg_f1score: 0.933
# U:avg_union_len: 29.2
# I:avg_acc: 0.882
# I:avg_rocaucscore: 0.961
# I:avg_f1score: 0.93
# I:avg_intersection_len: 28.8
# -----------reliefF,OVO----------
# U:avg_acc: 0.854
# U:avg_rocaucscore: 0.933
# U:avg_f1score: 0.893
# U:avg_union_len: 33.0
# I:avg_acc: 0.781
# I:avg_rocaucscore: 0.908
# I:avg_f1score: 0.825
# I:avg_intersection_len: 16.2
# -----------variance,OVA----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.886
# I:avg_rocaucscore: 0.93
# I:avg_f1score: 0.881
# I:avg_intersection_len: 35.0
# -----------variance,OVO----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.364
# I:avg_rocaucscore: 0.612
# I:avg_f1score: 0.244
# I:avg_intersection_len: 7.8
# -----------PCA,OVA----------
# U:avg_acc: 0.873
# U:avg_rocaucscore: 0.923
# U:avg_f1score: 0.866
# U:avg_union_len: 28.0
# I:avg_acc: 0.873
# I:avg_rocaucscore: 0.923
# I:avg_f1score: 0.866
# I:avg_intersection_len: 28.0
# -----------PCA,OVO----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.881
# U:avg_union_len: 35.0
# I:avg_acc: 0.515
# I:avg_rocaucscore: 0.711
# I:avg_f1score: 0.439
# I:avg_intersection_len: 11.8
# Path of read in data: ../datasets/4_waveform.csv
# waveform
# -----------mi,OVA----------
# U:avg_acc: 0.815
# U:avg_rocaucscore: 0.861
# U:avg_f1score: 0.815
# U:avg_union_len: 38.6
# I:avg_acc: 0.832
# I:avg_rocaucscore: 0.874
# I:avg_f1score: 0.832
# I:avg_intersection_len: 25.0
# -----------mi,OVO----------
# U:avg_acc: 0.813
# U:avg_rocaucscore: 0.86
# U:avg_f1score: 0.813
# U:avg_union_len: 38.8
# I:avg_acc: 0.82
# I:avg_rocaucscore: 0.865
# I:avg_f1score: 0.82
# I:avg_intersection_len: 24.6
# -----------chi2,OVA----------
# U:avg_acc: 0.813
# U:avg_rocaucscore: 0.86
# U:avg_f1score: 0.813
# U:avg_union_len: 37.6
# I:avg_acc: 0.828
# I:avg_rocaucscore: 0.871
# I:avg_f1score: 0.828
# I:avg_intersection_len: 23.6
# -----------chi2,OVO----------
# U:avg_acc: 0.817
# U:avg_rocaucscore: 0.863
# U:avg_f1score: 0.816
# U:avg_union_len: 37.0
# I:avg_acc: 0.824
# I:avg_rocaucscore: 0.868
# I:avg_f1score: 0.824
# I:avg_intersection_len: 24.0
# -----------anova,OVA----------
# U:avg_acc: 0.813
# U:avg_rocaucscore: 0.86
# U:avg_f1score: 0.813
# U:avg_union_len: 37.6
# I:avg_acc: 0.828
# I:avg_rocaucscore: 0.871
# I:avg_f1score: 0.828
# I:avg_intersection_len: 23.6
# -----------anova,OVO----------
# U:avg_acc: 0.818
# U:avg_rocaucscore: 0.863
# U:avg_f1score: 0.817
# U:avg_union_len: 37.2
# I:avg_acc: 0.808
# I:avg_rocaucscore: 0.856
# I:avg_f1score: 0.807
# I:avg_intersection_len: 23.4
# -----------reliefF,OVA----------
# U:avg_acc: 0.806
# U:avg_rocaucscore: 0.854
# U:avg_f1score: 0.806
# U:avg_union_len: 38.2
# I:avg_acc: 0.755
# I:avg_rocaucscore: 0.816
# I:avg_f1score: 0.754
# I:avg_intersection_len: 27.6
# -----------reliefF,OVO----------
# U:avg_acc: 0.786
# U:avg_rocaucscore: 0.84
# U:avg_f1score: 0.786
# U:avg_union_len: 35.8
# I:avg_acc: 0.666
# I:avg_rocaucscore: 0.75
# I:avg_f1score: 0.665
# I:avg_intersection_len: 29.8
# -----------variance,OVA----------
# U:avg_acc: 0.812
# U:avg_rocaucscore: 0.859
# U:avg_f1score: 0.812
# U:avg_union_len: 40.0
# I:avg_acc: 0.812
# I:avg_rocaucscore: 0.859
# I:avg_f1score: 0.812
# I:avg_intersection_len: 40.0
# -----------variance,OVO----------
# U:avg_acc: 0.812
# U:avg_rocaucscore: 0.859
# U:avg_f1score: 0.812
# U:avg_union_len: 40.0
# I:avg_acc: 0.812
# I:avg_rocaucscore: 0.859
# I:avg_f1score: 0.812
# I:avg_intersection_len: 40.0
# -----------PCA,OVA----------
# U:avg_acc: 0.745
# U:avg_rocaucscore: 0.809
# U:avg_f1score: 0.744
# U:avg_union_len: 32.0
# I:avg_acc: 0.745
# I:avg_rocaucscore: 0.809
# I:avg_f1score: 0.744
# I:avg_intersection_len: 32.0
# -----------PCA,OVO----------
# U:avg_acc: 0.799
# U:avg_rocaucscore: 0.85
# U:avg_f1score: 0.799
# U:avg_union_len: 38.0
# I:avg_acc: 0.577
# I:avg_rocaucscore: 0.683
# I:avg_f1score: 0.57
# I:avg_intersection_len: 26.0
# Path of read in data: ../datasets/5_Splice.csv
# Splice
# -----------mi,OVA----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.769
# U:avg_f1score: 0.686
# U:avg_union_len: 59.0
# I:avg_acc: 0.732
# I:avg_rocaucscore: 0.801
# I:avg_f1score: 0.717
# I:avg_intersection_len: 35.0
# -----------mi,OVO----------
# U:avg_acc: 0.701
# U:avg_rocaucscore: 0.765
# U:avg_f1score: 0.682
# U:avg_union_len: 58.6
# I:avg_acc: 0.718
# I:avg_rocaucscore: 0.781
# I:avg_f1score: 0.698
# I:avg_intersection_len: 32.8
# -----------chi2,OVA----------
# U:avg_acc: 0.708
# U:avg_rocaucscore: 0.769
# U:avg_f1score: 0.689
# U:avg_union_len: 57.4
# I:avg_acc: 0.752
# I:avg_rocaucscore: 0.818
# I:avg_f1score: 0.74
# I:avg_intersection_len: 32.0
# -----------chi2,OVO----------
# U:avg_acc: 0.704
# U:avg_rocaucscore: 0.768
# U:avg_f1score: 0.687
# U:avg_union_len: 58.0
# I:avg_acc: 0.716
# I:avg_rocaucscore: 0.773
# I:avg_f1score: 0.692
# I:avg_intersection_len: 30.0
# -----------anova,OVA----------
# U:avg_acc: 0.711
# U:avg_rocaucscore: 0.771
# U:avg_f1score: 0.691
# U:avg_union_len: 57.6
# I:avg_acc: 0.76
# I:avg_rocaucscore: 0.824
# I:avg_f1score: 0.748
# I:avg_intersection_len: 31.8
# -----------anova,OVO----------
# U:avg_acc: 0.704
# U:avg_rocaucscore: 0.768
# U:avg_f1score: 0.686
# U:avg_union_len: 58.4
# I:avg_acc: 0.715
# I:avg_rocaucscore: 0.781
# I:avg_f1score: 0.695
# I:avg_intersection_len: 29.8
# -----------reliefF,OVA----------
# U:avg_acc: 0.718
# U:avg_rocaucscore: 0.783
# U:avg_f1score: 0.705
# U:avg_union_len: 54.4
# I:avg_acc: 0.735
# I:avg_rocaucscore: 0.797
# I:avg_f1score: 0.717
# I:avg_intersection_len: 42.8
# -----------reliefF,OVO----------
# U:avg_acc: 0.705
# U:avg_rocaucscore: 0.77
# U:avg_f1score: 0.689
# U:avg_union_len: 59.6
# I:avg_acc: 0.723
# I:avg_rocaucscore: 0.784
# I:avg_f1score: 0.7
# I:avg_intersection_len: 35.8
# -----------variance,OVA----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.767
# U:avg_f1score: 0.685
# U:avg_union_len: 60.0
# I:avg_acc: 0.7
# I:avg_rocaucscore: 0.767
# I:avg_f1score: 0.685
# I:avg_intersection_len: 60.0
# -----------variance,OVO----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.767
# U:avg_f1score: 0.685
# U:avg_union_len: 60.0
# I:avg_acc: 0.7
# I:avg_rocaucscore: 0.767
# I:avg_f1score: 0.685
# I:avg_intersection_len: 60.0
# -----------PCA,OVA----------
# U:avg_acc: 0.659
# U:avg_rocaucscore: 0.72
# U:avg_f1score: 0.627
# U:avg_union_len: 48.0
# I:avg_acc: 0.659
# I:avg_rocaucscore: 0.72
# I:avg_f1score: 0.627
# I:avg_intersection_len: 48.0
# -----------PCA,OVO----------
# U:avg_acc: 0.697
# U:avg_rocaucscore: 0.762
# U:avg_f1score: 0.68
# U:avg_union_len: 59.4
# I:avg_acc: 0.609
# I:avg_rocaucscore: 0.679
# I:avg_f1score: 0.571
# I:avg_intersection_len: 32.0
# Path of read in data: ../datasets/6_urban_land_cover.csv
# urban_land_cover
# -----------mi,OVA----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 147.0
# I:avg_acc: 0.586
# I:avg_rocaucscore: 0.736
# I:avg_f1score: 0.531
# I:avg_intersection_len: 42.4
# -----------mi,OVO----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 147.0
# I:avg_acc: 0.524
# I:avg_rocaucscore: 0.707
# I:avg_f1score: 0.475
# I:avg_intersection_len: 16.4
# -----------chi2,OVA----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 147.0
# I:avg_acc: 0.706
# I:avg_rocaucscore: 0.825
# I:avg_f1score: 0.69
# I:avg_intersection_len: 19.8
# -----------chi2,OVO----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 132.2
# I:avg_acc: 0.394
# I:avg_rocaucscore: 0.64
# I:avg_f1score: 0.354
# I:avg_intersection_len: 19.4
# -----------anova,OVA----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 147.0
# I:avg_acc: 0.663
# I:avg_rocaucscore: 0.787
# I:avg_f1score: 0.626
# I:avg_intersection_len: 16.8
# -----------anova,OVO----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 132.2
# I:avg_acc: 0.404
# I:avg_rocaucscore: 0.646
# I:avg_f1score: 0.369
# I:avg_intersection_len: 22.0
# -----------reliefF,OVA----------
# U:avg_acc: 0.425
# U:avg_rocaucscore: 0.634
# U:avg_f1score: 0.346
# U:avg_union_len: 127.8
# I:avg_acc: 0.41
# I:avg_rocaucscore: 0.625
# I:avg_f1score: 0.331
# I:avg_intersection_len: 111.6
# -----------reliefF,OVO----------
# U:avg_acc: 0.42
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.377
# U:avg_union_len: 141.0
# I:avg_acc: 0.561
# I:avg_rocaucscore: 0.707
# I:avg_f1score: 0.469
# I:avg_intersection_len: 86.6
# -----------variance,OVA----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 147.0
# I:avg_acc: 0.463
# I:avg_rocaucscore: 0.667
# I:avg_f1score: 0.415
# I:avg_intersection_len: 147.0
# -----------variance,OVO----------
# U:avg_acc: 0.463
# U:avg_rocaucscore: 0.667
# U:avg_f1score: 0.415
# U:avg_union_len: 132.2
# I:avg_acc: 0.463
# I:avg_rocaucscore: 0.667
# I:avg_f1score: 0.415
# I:avg_intersection_len: 119.0
# -----------PCA,OVA----------
# U:avg_acc: 0.467
# U:avg_rocaucscore: 0.675
# U:avg_f1score: 0.433
# U:avg_union_len: 118.0
# I:avg_acc: 0.467
# I:avg_rocaucscore: 0.675
# I:avg_f1score: 0.433
# I:avg_intersection_len: 118.0
# -----------PCA,OVO----------
# U:avg_acc: 0.467
# U:avg_rocaucscore: 0.675
# U:avg_f1score: 0.433
# U:avg_union_len: 122.4
# I:avg_acc: 0.484
# I:avg_rocaucscore: 0.699
# I:avg_f1score: 0.468
# I:avg_intersection_len: 51.4
# Path of read in data: ../datasets/7_SCADI.csv
# SCADI
# -----------mi,OVA----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 203.2
# I:avg_acc: 0.762
# I:avg_rocaucscore: 0.802
# I:avg_f1score: 0.599
# I:avg_intersection_len: 106.2
# -----------mi,OVO----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 205.0
# I:avg_acc: 0.748
# I:avg_rocaucscore: 0.795
# I:avg_f1score: 0.582
# I:avg_intersection_len: 100.8
# -----------chi2,OVA----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 164.0
# I:avg_acc: 0.788
# I:avg_rocaucscore: 0.825
# I:avg_f1score: 0.637
# I:avg_intersection_len: 164.0
# -----------chi2,OVO----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 186.4
# I:avg_acc: 0.764
# I:avg_rocaucscore: 0.809
# I:avg_f1score: 0.6
# I:avg_intersection_len: 120.4
# -----------anova,OVA----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 164.0
# I:avg_acc: 0.788
# I:avg_rocaucscore: 0.825
# I:avg_f1score: 0.637
# I:avg_intersection_len: 164.0
# -----------anova,OVO----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 186.4
# I:avg_acc: 0.764
# I:avg_rocaucscore: 0.809
# I:avg_f1score: 0.6
# I:avg_intersection_len: 120.4
# -----------reliefF,OVA----------
# U:avg_acc: 0.804
# U:avg_rocaucscore: 0.831
# U:avg_f1score: 0.661
# U:avg_union_len: 178.0
# I:avg_acc: 0.8
# I:avg_rocaucscore: 0.826
# I:avg_f1score: 0.636
# I:avg_intersection_len: 151.0
# -----------reliefF,OVO----------
# U:avg_acc: 0.774
# U:avg_rocaucscore: 0.808
# U:avg_f1score: 0.597
# U:avg_union_len: 204.0
# I:avg_acc: 0.732
# I:avg_rocaucscore: 0.784
# I:avg_f1score: 0.544
# I:avg_intersection_len: 76.2
# -----------variance,OVA----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 140.0
# I:avg_acc: 0.788
# I:avg_rocaucscore: 0.825
# I:avg_f1score: 0.637
# I:avg_intersection_len: 140.0
# -----------variance,OVO----------
# U:avg_acc: 0.788
# U:avg_rocaucscore: 0.825
# U:avg_f1score: 0.637
# U:avg_union_len: 140.0
# I:avg_acc: 0.56
# I:avg_rocaucscore: 0.664
# I:avg_f1score: 0.367
# I:avg_intersection_len: 20.6
# -----------PCA,OVA----------
# U:avg_acc: 0.699
# U:avg_rocaucscore: 0.796
# U:avg_f1score: 0.578
# U:avg_union_len: 60.8
# I:avg_acc: 0.699
# I:avg_rocaucscore: 0.796
# I:avg_f1score: 0.578
# I:avg_intersection_len: 60.8
# -----------PCA,OVO----------
# U:avg_acc: 0.623
# U:avg_rocaucscore: 0.73
# U:avg_f1score: 0.46
# U:avg_union_len: 36.2
# I:avg_acc: 0.467
# I:avg_rocaucscore: 0.651
# I:avg_f1score: 0.341
# I:avg_intersection_len: 5.8
# Path of read in data: ../datasets/9_lung_discrete.csv
# lung_discrete
# -----------mi,OVA----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.867
# I:avg_rocaucscore: 0.893
# I:avg_f1score: 0.787
# I:avg_intersection_len: 87.2
# -----------mi,OVO----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.796
# I:avg_rocaucscore: 0.862
# I:avg_f1score: 0.715
# I:avg_intersection_len: 34.4
# -----------chi2,OVA----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.765
# I:avg_rocaucscore: 0.824
# I:avg_f1score: 0.66
# I:avg_intersection_len: 71.8
# -----------chi2,OVO----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.487
# I:avg_rocaucscore: 0.69
# I:avg_f1score: 0.385
# I:avg_intersection_len: 4.8
# -----------anova,OVA----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.793
# I:avg_rocaucscore: 0.846
# I:avg_f1score: 0.689
# I:avg_intersection_len: 69.8
# -----------anova,OVO----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.287
# I:avg_rocaucscore: 0.59
# I:avg_f1score: 0.216
# I:avg_intersection_len: 2.2
# -----------reliefF,OVA----------
# U:avg_acc: 0.791
# U:avg_rocaucscore: 0.828
# U:avg_f1score: 0.652
# U:avg_union_len: 299.6
# I:avg_acc: 0.834
# I:avg_rocaucscore: 0.864
# I:avg_f1score: 0.728
# I:avg_intersection_len: 211.6
# -----------reliefF,OVO----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.767
# I:avg_rocaucscore: 0.822
# I:avg_f1score: 0.645
# I:avg_intersection_len: 45.0
# -----------variance,OVA----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.805
# I:avg_rocaucscore: 0.843
# I:avg_f1score: 0.694
# I:avg_intersection_len: 325.0
# -----------variance,OVO----------
# U:avg_acc: 0.805
# U:avg_rocaucscore: 0.843
# U:avg_f1score: 0.694
# U:avg_union_len: 325.0
# I:avg_acc: 0.782
# I:avg_rocaucscore: 0.832
# I:avg_f1score: 0.664
# I:avg_intersection_len: 313.2
# -----------PCA,OVA----------
# U:avg_acc: 0.822
# U:avg_rocaucscore: 0.864
# U:avg_f1score: 0.713
# U:avg_union_len: 58.4
# I:avg_acc: 0.822
# I:avg_rocaucscore: 0.864
# I:avg_f1score: 0.713
# I:avg_intersection_len: 58.4
# -----------PCA,OVO----------
# U:avg_acc: 0.779
# U:avg_rocaucscore: 0.83
# U:avg_f1score: 0.635
# U:avg_union_len: 30.2
# I:avg_acc: 0.525
# I:avg_rocaucscore: 0.686
# I:avg_f1score: 0.372
# I:avg_intersection_len: 7.6
# Path of read in data: ../datasets/11_CNAE-9.csv
# CNAE-9
# -----------mi,OVA----------
# U:avg_acc: 0.851
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 855.6
# I:avg_acc: 0.717
# I:avg_rocaucscore: 0.841
# I:avg_f1score: 0.715
# I:avg_intersection_len: 486.6
# -----------mi,OVO----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 856.0
# I:avg_acc: 0.672
# I:avg_rocaucscore: 0.816
# I:avg_f1score: 0.671
# I:avg_intersection_len: 469.8
# -----------chi2,OVA----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 775.4
# I:avg_acc: 0.865
# I:avg_rocaucscore: 0.924
# I:avg_f1score: 0.866
# I:avg_intersection_len: 621.8
# -----------chi2,OVO----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 833.8
# I:avg_acc: 0.786
# I:avg_rocaucscore: 0.88
# I:avg_f1score: 0.79
# I:avg_intersection_len: 573.6
# -----------anova,OVA----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 775.4
# I:avg_acc: 0.868
# I:avg_rocaucscore: 0.926
# I:avg_f1score: 0.865
# I:avg_intersection_len: 623.8
# -----------anova,OVO----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 833.8
# I:avg_acc: 0.786
# I:avg_rocaucscore: 0.88
# I:avg_f1score: 0.79
# I:avg_intersection_len: 573.6
# -----------reliefF,OVA----------
# U:avg_acc: 0.641
# U:avg_rocaucscore: 0.798
# U:avg_f1score: 0.664
# U:avg_union_len: 731.6
# I:avg_acc: 0.445
# I:avg_rocaucscore: 0.688
# I:avg_f1score: 0.477
# I:avg_intersection_len: 659.0
# -----------reliefF,OVO----------
# U:avg_acc: 0.873
# U:avg_rocaucscore: 0.929
# U:avg_f1score: 0.871
# U:avg_union_len: 848.6
# I:avg_acc: 0.127
# I:avg_rocaucscore: 0.509
# I:avg_f1score: 0.05
# I:avg_intersection_len: 108.8
# -----------variance,OVA----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 775.4
# I:avg_acc: 0.85
# I:avg_rocaucscore: 0.916
# I:avg_f1score: 0.846
# I:avg_intersection_len: 775.4
# -----------variance,OVO----------
# U:avg_acc: 0.85
# U:avg_rocaucscore: 0.916
# U:avg_f1score: 0.846
# U:avg_union_len: 775.4
# I:avg_acc: 0.207
# I:avg_rocaucscore: 0.554
# I:avg_f1score: 0.15
# I:avg_intersection_len: 14.0
# -----------PCA,OVA----------
# U:avg_acc: 0.792
# U:avg_rocaucscore: 0.883
# U:avg_f1score: 0.797
# U:avg_union_len: 685.0
# I:avg_acc: 0.792
# I:avg_rocaucscore: 0.883
# I:avg_f1score: 0.797
# I:avg_intersection_len: 685.0
# -----------PCA,OVO----------
# U:avg_acc: 0.517
# U:avg_rocaucscore: 0.728
# U:avg_f1score: 0.534
# U:avg_union_len: 238.6
# I:avg_acc: 0.297
# I:avg_rocaucscore: 0.605
# I:avg_f1score: 0.299
# I:avg_intersection_len: 118.6
# Path of read in data: ../datasets/12_oh15.csv
# oh15
# -----------mi,OVA----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3098.8
# I:avg_acc: 0.447
# I:avg_rocaucscore: 0.642
# I:avg_f1score: 0.367
# I:avg_intersection_len: 1776.4
# -----------mi,OVO----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3100.0
# I:avg_acc: 0.44
# I:avg_rocaucscore: 0.636
# I:avg_f1score: 0.352
# I:avg_intersection_len: 1752.2
# -----------chi2,OVA----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3093.0
# I:avg_acc: 0.62
# I:avg_rocaucscore: 0.768
# I:avg_f1score: 0.605
# I:avg_intersection_len: 998.0
# -----------chi2,OVO----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3096.4
# I:avg_acc: 0.417
# I:avg_rocaucscore: 0.625
# I:avg_f1score: 0.32
# I:avg_intersection_len: 1151.8
# -----------anova,OVA----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3093.2
# I:avg_acc: 0.626
# I:avg_rocaucscore: 0.764
# I:avg_f1score: 0.587
# I:avg_intersection_len: 940.8
# -----------anova,OVO----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3096.4
# I:avg_acc: 0.417
# I:avg_rocaucscore: 0.625
# I:avg_f1score: 0.32
# I:avg_intersection_len: 1151.8
# -----------reliefF,OVA----------
# U:avg_acc: 0.442
# U:avg_rocaucscore: 0.643
# U:avg_f1score: 0.381
# U:avg_union_len: 3085.4
# I:avg_acc: 0.282
# I:avg_rocaucscore: 0.565
# I:avg_f1score: 0.205
# I:avg_intersection_len: 1713.2
# -----------reliefF,OVO----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3100.0
# I:avg_acc: 0.17
# I:avg_rocaucscore: 0.532
# I:avg_f1score: 0.128
# I:avg_intersection_len: 267.2
# -----------variance,OVA----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3093.2
# I:avg_acc: 0.445
# I:avg_rocaucscore: 0.644
# I:avg_f1score: 0.386
# I:avg_intersection_len: 3093.2
# -----------variance,OVO----------
# U:avg_acc: 0.445
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.386
# U:avg_union_len: 3093.2
# I:avg_acc: 0.405
# I:avg_rocaucscore: 0.612
# I:avg_f1score: 0.285
# I:avg_intersection_len: 322.2
# -----------PCA,OVA----------
# U:avg_acc: 0.446
# U:avg_rocaucscore: 0.649
# U:avg_f1score: 0.367
# U:avg_union_len: 730.4
# I:avg_acc: 0.446
# I:avg_rocaucscore: 0.649
# I:avg_f1score: 0.367
# I:avg_intersection_len: 730.4
# -----------PCA,OVO----------
# U:avg_acc: 0.352
# U:avg_rocaucscore: 0.603
# U:avg_f1score: 0.275
# U:avg_union_len: 248.8
# I:avg_acc: 0.275
# I:avg_rocaucscore: 0.559
# I:avg_f1score: 0.173
# I:avg_intersection_len: 86.6
# Path of read in data: ../datasets/13_lung.csv
# lung
# -----------mi,OVA----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3306.6
# I:avg_acc: 0.946
# I:avg_rocaucscore: 0.91
# I:avg_f1score: 0.853
# I:avg_intersection_len: 1233.4
# -----------mi,OVO----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3311.0
# I:avg_acc: 0.93
# I:avg_rocaucscore: 0.881
# I:avg_f1score: 0.802
# I:avg_intersection_len: 1466.8
# -----------chi2,OVA----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3304.0
# I:avg_acc: 0.946
# I:avg_rocaucscore: 0.91
# I:avg_f1score: 0.853
# I:avg_intersection_len: 1152.8
# -----------chi2,OVO----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3062.8
# I:avg_acc: 0.935
# I:avg_rocaucscore: 0.898
# I:avg_f1score: 0.822
# I:avg_intersection_len: 1681.6
# -----------anova,OVA----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3307.4
# I:avg_acc: 0.945
# I:avg_rocaucscore: 0.924
# I:avg_f1score: 0.889
# I:avg_intersection_len: 1098.2
# -----------anova,OVO----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3096.2
# I:avg_acc: 0.945
# I:avg_rocaucscore: 0.915
# I:avg_f1score: 0.853
# I:avg_intersection_len: 1435.8
# -----------reliefF,OVA----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 2667.8
# I:avg_acc: 0.946
# I:avg_rocaucscore: 0.93
# I:avg_f1score: 0.89
# I:avg_intersection_len: 2633.2
# -----------reliefF,OVO----------
# U:avg_acc: 0.951
# U:avg_rocaucscore: 0.931
# U:avg_f1score: 0.894
# U:avg_union_len: 3258.0
# I:avg_acc: 0.945
# I:avg_rocaucscore: 0.936
# I:avg_f1score: 0.899
# I:avg_intersection_len: 1719.4
# -----------variance,OVA----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 3312.0
# I:avg_acc: 0.946
# I:avg_rocaucscore: 0.93
# I:avg_f1score: 0.89
# I:avg_intersection_len: 3312.0
# -----------variance,OVO----------
# U:avg_acc: 0.946
# U:avg_rocaucscore: 0.93
# U:avg_f1score: 0.89
# U:avg_union_len: 2927.6
# I:avg_acc: 0.941
# I:avg_rocaucscore: 0.894
# I:avg_f1score: 0.825
# I:avg_intersection_len: 1391.0
# -----------PCA,OVA----------
# U:avg_acc: 0.886
# U:avg_rocaucscore: 0.845
# U:avg_f1score: 0.751
# U:avg_union_len: 163.2
# I:avg_acc: 0.886
# I:avg_rocaucscore: 0.845
# I:avg_f1score: 0.751
# I:avg_intersection_len: 163.2
# -----------PCA,OVO----------
# U:avg_acc: 0.866
# U:avg_rocaucscore: 0.811
# U:avg_f1score: 0.684
# U:avg_union_len: 129.4
# I:avg_acc: 0.793
# I:avg_rocaucscore: 0.679
# I:avg_f1score: 0.474
# I:avg_intersection_len: 18.4
# Path of read in data: ../datasets/14_TOX_171.csv
# TOX_171
# -----------mi,OVA----------
# U:avg_acc: 0.474
# U:avg_rocaucscore: 0.649
# U:avg_f1score: 0.476
# U:avg_union_len: 5667.0
# I:avg_acc: 0.48
# I:avg_rocaucscore: 0.651
# I:avg_f1score: 0.476
# I:avg_intersection_len: 3060.6
# -----------mi,OVO----------
# U:avg_acc: 0.468
# U:avg_rocaucscore: 0.645
# U:avg_f1score: 0.469
# U:avg_union_len: 5695.2
# I:avg_acc: 0.497
# I:avg_rocaucscore: 0.665
# I:avg_f1score: 0.49
# I:avg_intersection_len: 2616.4
# -----------chi2,OVA----------
# U:avg_acc: 0.462
# U:avg_rocaucscore: 0.642
# U:avg_f1score: 0.463
# U:avg_union_len: 5695.6
# I:avg_acc: 0.491
# I:avg_rocaucscore: 0.66
# I:avg_f1score: 0.481
# I:avg_intersection_len: 2524.4
# -----------chi2,OVO----------
# U:avg_acc: 0.456
# U:avg_rocaucscore: 0.637
# U:avg_f1score: 0.46
# U:avg_union_len: 5708.4
# I:avg_acc: 0.474
# I:avg_rocaucscore: 0.65
# I:avg_f1score: 0.467
# I:avg_intersection_len: 1674.4
# -----------anova,OVA----------
# U:avg_acc: 0.462
# U:avg_rocaucscore: 0.642
# U:avg_f1score: 0.463
# U:avg_union_len: 5697.4
# I:avg_acc: 0.509
# I:avg_rocaucscore: 0.673
# I:avg_f1score: 0.5
# I:avg_intersection_len: 2517.6
# -----------anova,OVO----------
# U:avg_acc: 0.462
# U:avg_rocaucscore: 0.641
# U:avg_f1score: 0.466
# U:avg_union_len: 5708.6
# I:avg_acc: 0.469
# I:avg_rocaucscore: 0.646
# I:avg_f1score: 0.462
# I:avg_intersection_len: 1661.4
# -----------reliefF,OVA----------
# U:avg_acc: 0.462
# U:avg_rocaucscore: 0.64
# U:avg_f1score: 0.459
# U:avg_union_len: 4609.4
# I:avg_acc: 0.462
# I:avg_rocaucscore: 0.64
# I:avg_f1score: 0.459
# I:avg_intersection_len: 4591.4
# -----------reliefF,OVO----------
# U:avg_acc: 0.451
# U:avg_rocaucscore: 0.633
# U:avg_f1score: 0.451
# U:avg_union_len: 5385.6
# I:avg_acc: 0.485
# I:avg_rocaucscore: 0.656
# I:avg_f1score: 0.477
# I:avg_intersection_len: 3467.2
# -----------variance,OVA----------
# U:avg_acc: 0.462
# U:avg_rocaucscore: 0.641
# U:avg_f1score: 0.464
# U:avg_union_len: 5748.0
# I:avg_acc: 0.462
# I:avg_rocaucscore: 0.641
# I:avg_f1score: 0.464
# I:avg_intersection_len: 5748.0
# -----------variance,OVO----------
# U:avg_acc: 0.462
# U:avg_rocaucscore: 0.641
# U:avg_f1score: 0.464
# U:avg_union_len: 5748.0
# I:avg_acc: 0.462
# I:avg_rocaucscore: 0.641
# I:avg_f1score: 0.464
# I:avg_intersection_len: 5748.0
# -----------PCA,OVA----------
# U:avg_acc: 0.386
# U:avg_rocaucscore: 0.591
# U:avg_f1score: 0.367
# U:avg_union_len: 136.8
# I:avg_acc: 0.386
# I:avg_rocaucscore: 0.591
# I:avg_f1score: 0.367
# I:avg_intersection_len: 136.8
# -----------PCA,OVO----------
# U:avg_acc: 0.391
# U:avg_rocaucscore: 0.594
# U:avg_f1score: 0.383
# U:avg_union_len: 72.6
# I:avg_acc: 0.391
# I:avg_rocaucscore: 0.594
# I:avg_f1score: 0.39
# I:avg_intersection_len: 64.8
# Path of read in data: ../datasets/15_orlraws10P.csv
# orlraws10P
# -----------mi,OVA----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.97
# I:avg_rocaucscore: 0.983
# I:avg_f1score: 0.968
# I:avg_intersection_len: 1839.2
# -----------mi,OVO----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.91
# I:avg_rocaucscore: 0.95
# I:avg_f1score: 0.905
# I:avg_intersection_len: 128.0
# -----------chi2,OVA----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.97
# I:avg_rocaucscore: 0.983
# I:avg_f1score: 0.968
# I:avg_intersection_len: 1715.4
# -----------chi2,OVO----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.91
# I:avg_rocaucscore: 0.95
# I:avg_f1score: 0.898
# I:avg_intersection_len: 49.6
# -----------anova,OVA----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.95
# I:avg_rocaucscore: 0.972
# I:avg_f1score: 0.943
# I:avg_intersection_len: 1425.2
# -----------anova,OVO----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.81
# I:avg_rocaucscore: 0.894
# I:avg_f1score: 0.784
# I:avg_intersection_len: 38.0
# -----------reliefF,OVA----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 8604.2
# I:avg_acc: 0.89
# I:avg_rocaucscore: 0.939
# I:avg_f1score: 0.869
# I:avg_intersection_len: 7976.8
# -----------reliefF,OVO----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10179.4
# I:avg_acc: 0.92
# I:avg_rocaucscore: 0.956
# I:avg_f1score: 0.905
# I:avg_intersection_len: 4249.6
# -----------variance,OVA----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.9
# I:avg_rocaucscore: 0.944
# I:avg_f1score: 0.879
# I:avg_intersection_len: 10304.0
# -----------variance,OVO----------
# U:avg_acc: 0.9
# U:avg_rocaucscore: 0.944
# U:avg_f1score: 0.879
# U:avg_union_len: 10304.0
# I:avg_acc: 0.9
# I:avg_rocaucscore: 0.944
# I:avg_f1score: 0.879
# I:avg_intersection_len: 10304.0
# -----------PCA,OVA----------
# U:avg_acc: 0.66
# U:avg_rocaucscore: 0.811
# U:avg_f1score: 0.626
# U:avg_union_len: 80.0
# I:avg_acc: 0.66
# I:avg_rocaucscore: 0.811
# I:avg_f1score: 0.626
# I:avg_intersection_len: 80.0
# -----------PCA,OVO----------
# U:avg_acc: 0.61
# U:avg_rocaucscore: 0.783
# U:avg_f1score: 0.584
# U:avg_union_len: 26.4
# I:avg_acc: 0.67
# I:avg_rocaucscore: 0.817
# I:avg_f1score: 0.63
# I:avg_intersection_len: 15.0
# Path of read in data: ../datasets/16_CLL_SUB_111.csv
# CLL_SUB_111
# -----------mi,OVA----------
# U:avg_acc: 0.551
# U:avg_rocaucscore: 0.643
# U:avg_f1score: 0.534
# U:avg_union_len: 10857.0
# I:avg_acc: 0.523
# I:avg_rocaucscore: 0.624
# I:avg_f1score: 0.526
# I:avg_intersection_len: 6965.4
# -----------mi,OVO----------
# U:avg_acc: 0.551
# U:avg_rocaucscore: 0.643
# U:avg_f1score: 0.534
# U:avg_union_len: 10873.8
# I:avg_acc: 0.514
# I:avg_rocaucscore: 0.617
# I:avg_f1score: 0.517
# I:avg_intersection_len: 6840.8
# -----------chi2,OVA----------
# U:avg_acc: 0.542
# U:avg_rocaucscore: 0.637
# U:avg_f1score: 0.529
# U:avg_union_len: 10935.6
# I:avg_acc: 0.541
# I:avg_rocaucscore: 0.638
# I:avg_f1score: 0.528
# I:avg_intersection_len: 5789.0
# -----------chi2,OVO----------
# U:avg_acc: 0.542
# U:avg_rocaucscore: 0.637
# U:avg_f1score: 0.529
# U:avg_union_len: 10925.8
# I:avg_acc: 0.577
# I:avg_rocaucscore: 0.661
# I:avg_f1score: 0.554
# I:avg_intersection_len: 6551.2
# -----------anova,OVA----------
# U:avg_acc: 0.551
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.535
# U:avg_union_len: 10957.0
# I:avg_acc: 0.532
# I:avg_rocaucscore: 0.63
# I:avg_f1score: 0.534
# I:avg_intersection_len: 5737.4
# -----------anova,OVO----------
# U:avg_acc: 0.542
# U:avg_rocaucscore: 0.637
# U:avg_f1score: 0.529
# U:avg_union_len: 10936.2
# I:avg_acc: 0.569
# I:avg_rocaucscore: 0.655
# I:avg_f1score: 0.548
# I:avg_intersection_len: 6521.4
# -----------reliefF,OVA----------
# U:avg_acc: 0.532
# U:avg_rocaucscore: 0.63
# U:avg_f1score: 0.515
# U:avg_union_len: 9146.6
# I:avg_acc: 0.505
# I:avg_rocaucscore: 0.612
# I:avg_f1score: 0.498
# I:avg_intersection_len: 8999.8
# -----------reliefF,OVO----------
# U:avg_acc: 0.532
# U:avg_rocaucscore: 0.63
# U:avg_f1score: 0.515
# U:avg_union_len: 9710.6
# I:avg_acc: 0.513
# I:avg_rocaucscore: 0.618
# I:avg_f1score: 0.507
# I:avg_intersection_len: 8391.2
# -----------variance,OVA----------
# U:avg_acc: 0.551
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.535
# U:avg_union_len: 11340.0
# I:avg_acc: 0.551
# I:avg_rocaucscore: 0.644
# I:avg_f1score: 0.535
# I:avg_intersection_len: 11340.0
# -----------variance,OVO----------
# U:avg_acc: 0.551
# U:avg_rocaucscore: 0.644
# U:avg_f1score: 0.535
# U:avg_union_len: 11340.0
# I:avg_acc: 0.551
# I:avg_rocaucscore: 0.644
# I:avg_f1score: 0.535
# I:avg_intersection_len: 11340.0
# -----------PCA,OVA----------
# U:avg_acc: 0.632
# U:avg_rocaucscore: 0.711
# U:avg_f1score: 0.65
# U:avg_union_len: 88.8
# I:avg_acc: 0.632
# I:avg_rocaucscore: 0.711
# I:avg_f1score: 0.65
# I:avg_intersection_len: 88.8
# -----------PCA,OVO----------
# U:avg_acc: 0.669
# U:avg_rocaucscore: 0.723
# U:avg_f1score: 0.64
# U:avg_union_len: 80.0
# I:avg_acc: 0.595
# I:avg_rocaucscore: 0.673
# I:avg_f1score: 0.585
# I:avg_intersection_len: 47.4
# Path of read in data: ../datasets/CARCINOM.csv
# CARCINOM
# -----------mi,OVA----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9181.6
# I:avg_acc: 0.874
# I:avg_rocaucscore: 0.903
# I:avg_f1score: 0.801
# I:avg_intersection_len: 2639.6
# -----------mi,OVO----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9182.0
# I:avg_acc: 0.857
# I:avg_rocaucscore: 0.889
# I:avg_f1score: 0.778
# I:avg_intersection_len: 3771.8
# -----------chi2,OVA----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9180.4
# I:avg_acc: 0.887
# I:avg_rocaucscore: 0.917
# I:avg_f1score: 0.826
# I:avg_intersection_len: 1339.4
# -----------chi2,OVO----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9035.4
# I:avg_acc: 0.858
# I:avg_rocaucscore: 0.884
# I:avg_f1score: 0.778
# I:avg_intersection_len: 870.8
# -----------anova,OVA----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9180.4
# I:avg_acc: 0.881
# I:avg_rocaucscore: 0.915
# I:avg_f1score: 0.819
# I:avg_intersection_len: 848.4
# -----------anova,OVO----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9035.4
# I:avg_acc: 0.859
# I:avg_rocaucscore: 0.89
# I:avg_f1score: 0.775
# I:avg_intersection_len: 704.2
# -----------reliefF,OVA----------
# U:avg_acc: 0.869
# U:avg_rocaucscore: 0.907
# U:avg_f1score: 0.813
# U:avg_union_len: 8422.2
# I:avg_acc: 0.881
# I:avg_rocaucscore: 0.919
# I:avg_f1score: 0.841
# I:avg_intersection_len: 6150.4
# -----------reliefF,OVO----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9181.4
# I:avg_acc: 0.798
# I:avg_rocaucscore: 0.87
# I:avg_f1score: 0.743
# I:avg_intersection_len: 2520.4
# -----------variance,OVA----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 9180.4
# I:avg_acc: 0.874
# I:avg_rocaucscore: 0.909
# I:avg_f1score: 0.816
# I:avg_intersection_len: 9180.4
# -----------variance,OVO----------
# U:avg_acc: 0.874
# U:avg_rocaucscore: 0.909
# U:avg_f1score: 0.816
# U:avg_union_len: 8959.6
# I:avg_acc: 0.858
# I:avg_rocaucscore: 0.891
# I:avg_f1score: 0.781
# I:avg_intersection_len: 2873.4
# -----------PCA,OVA----------
# U:avg_acc: 0.675
# U:avg_rocaucscore: 0.772
# U:avg_f1score: 0.545
# U:avg_union_len: 139.2
# I:avg_acc: 0.675
# I:avg_rocaucscore: 0.772
# I:avg_f1score: 0.545
# I:avg_intersection_len: 139.2
# -----------PCA,OVO----------
# U:avg_acc: 0.623
# U:avg_rocaucscore: 0.763
# U:avg_f1score: 0.529
# U:avg_union_len: 43.8
# I:avg_acc: 0.419
# I:avg_rocaucscore: 0.647
# I:avg_f1score: 0.322
# I:avg_intersection_len: 9.8
# Path of read in data: ../datasets/GLIOMA.csv
# GLIOMA
# -----------mi,OVA----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.804
# U:avg_f1score: 0.678
# U:avg_union_len: 4396.4
# I:avg_acc: 0.74
# I:avg_rocaucscore: 0.828
# I:avg_f1score: 0.708
# I:avg_intersection_len: 2093.6
# -----------mi,OVO----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.804
# U:avg_f1score: 0.678
# U:avg_union_len: 4409.8
# I:avg_acc: 0.68
# I:avg_rocaucscore: 0.792
# I:avg_f1score: 0.659
# I:avg_intersection_len: 2184.4
# -----------chi2,OVA----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.804
# U:avg_f1score: 0.678
# U:avg_union_len: 4413.8
# I:avg_acc: 0.72
# I:avg_rocaucscore: 0.816
# I:avg_f1score: 0.691
# I:avg_intersection_len: 2083.4
# -----------chi2,OVO----------
# U:avg_acc: 0.68
# U:avg_rocaucscore: 0.793
# U:avg_f1score: 0.651
# U:avg_union_len: 4323.4
# I:avg_acc: 0.72
# I:avg_rocaucscore: 0.815
# I:avg_f1score: 0.706
# I:avg_intersection_len: 1819.0
# -----------anova,OVA----------
# U:avg_acc: 0.72
# U:avg_rocaucscore: 0.816
# U:avg_f1score: 0.694
# U:avg_union_len: 4401.0
# I:avg_acc: 0.74
# I:avg_rocaucscore: 0.827
# I:avg_f1score: 0.723
# I:avg_intersection_len: 2220.6
# -----------anova,OVO----------
# U:avg_acc: 0.68
# U:avg_rocaucscore: 0.793
# U:avg_f1score: 0.651
# U:avg_union_len: 4323.4
# I:avg_acc: 0.7
# I:avg_rocaucscore: 0.804
# I:avg_f1score: 0.674
# I:avg_intersection_len: 1671.0
# -----------reliefF,OVA----------
# U:avg_acc: 0.72
# U:avg_rocaucscore: 0.816
# U:avg_f1score: 0.708
# U:avg_union_len: 3869.8
# I:avg_acc: 0.7
# I:avg_rocaucscore: 0.805
# I:avg_f1score: 0.681
# I:avg_intersection_len: 3267.0
# -----------reliefF,OVO----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.804
# U:avg_f1score: 0.678
# U:avg_union_len: 4370.6
# I:avg_acc: 0.7
# I:avg_rocaucscore: 0.804
# I:avg_f1score: 0.692
# I:avg_intersection_len: 2315.2
# -----------variance,OVA----------
# U:avg_acc: 0.7
# U:avg_rocaucscore: 0.804
# U:avg_f1score: 0.678
# U:avg_union_len: 4432.0
# I:avg_acc: 0.7
# I:avg_rocaucscore: 0.804
# I:avg_f1score: 0.678
# I:avg_intersection_len: 4432.0
# -----------variance,OVO----------
# U:avg_acc: 0.68
# U:avg_rocaucscore: 0.793
# U:avg_f1score: 0.651
# U:avg_union_len: 4239.2
# I:avg_acc: 0.76
# I:avg_rocaucscore: 0.84
# I:avg_f1score: 0.73
# I:avg_intersection_len: 2046.2
# -----------PCA,OVA----------
# U:avg_acc: 0.68
# U:avg_rocaucscore: 0.792
# U:avg_f1score: 0.661
# U:avg_union_len: 40.0
# I:avg_acc: 0.68
# I:avg_rocaucscore: 0.792
# I:avg_f1score: 0.661
# I:avg_intersection_len: 40.0
# -----------PCA,OVO----------
# U:avg_acc: 0.64
# U:avg_rocaucscore: 0.784
# U:avg_f1score: 0.649
# U:avg_union_len: 23.6
# I:avg_acc: 0.62
# I:avg_rocaucscore: 0.778
# I:avg_f1score: 0.619
# I:avg_intersection_len: 16.2
# Path of read in data: ../datasets/AllBooks_baseline_DTM_Labelled.csv
# AllBooks_baseline_DTM_Labelled
# -----------mi,OVA----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 8249.2
# I:avg_acc: 0.429
# I:avg_rocaucscore: 0.621
# I:avg_f1score: 0.31
# I:avg_intersection_len: 4909.4
# -----------mi,OVO----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 8266.0
# I:avg_acc: 0.419
# I:avg_rocaucscore: 0.611
# I:avg_f1score: 0.284
# I:avg_intersection_len: 4872.2
# -----------chi2,OVA----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 7407.8
# I:avg_acc: 0.437
# I:avg_rocaucscore: 0.624
# I:avg_f1score: 0.334
# I:avg_intersection_len: 5220.2
# -----------chi2,OVO----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 8047.0
# I:avg_acc: 0.419
# I:avg_rocaucscore: 0.63
# I:avg_f1score: 0.339
# I:avg_intersection_len: 4954.2
# -----------anova,OVA----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 7407.8
# I:avg_acc: 0.424
# I:avg_rocaucscore: 0.623
# I:avg_f1score: 0.337
# I:avg_intersection_len: 5304.6
# -----------anova,OVO----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 8047.0
# I:avg_acc: 0.419
# I:avg_rocaucscore: 0.63
# I:avg_f1score: 0.339
# I:avg_intersection_len: 4954.2
# -----------reliefF,OVA----------
# U:avg_acc: 0.383
# U:avg_rocaucscore: 0.611
# U:avg_f1score: 0.295
# U:avg_union_len: 8218.0
# I:avg_acc: 0.274
# I:avg_rocaucscore: 0.502
# I:avg_f1score: 0.061
# I:avg_intersection_len: 4331.8
# -----------reliefF,OVO----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 8266.0
# I:avg_acc: 0.276
# I:avg_rocaucscore: 0.501
# I:avg_f1score: 0.055
# I:avg_intersection_len: 1375.4
# -----------variance,OVA----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 7407.8
# I:avg_acc: 0.392
# I:avg_rocaucscore: 0.614
# I:avg_f1score: 0.303
# I:avg_intersection_len: 7407.8
# -----------variance,OVO----------
# U:avg_acc: 0.392
# U:avg_rocaucscore: 0.614
# U:avg_f1score: 0.303
# U:avg_union_len: 7407.8
# I:avg_acc: 0.467
# I:avg_rocaucscore: 0.652
# I:avg_f1score: 0.37
# I:avg_intersection_len: 181.6
# -----------PCA,OVA----------
# U:avg_acc: 0.519
# U:avg_rocaucscore: 0.629
# U:avg_f1score: 0.359
# U:avg_union_len: 472.0
# I:avg_acc: 0.519
# I:avg_rocaucscore: 0.629
# I:avg_f1score: 0.359
# I:avg_intersection_len: 472.0
# -----------PCA,OVO----------
# U:avg_acc: 0.489
# U:avg_rocaucscore: 0.612
# U:avg_f1score: 0.31
# U:avg_union_len: 280.8
# I:avg_acc: 0.371
# I:avg_rocaucscore: 0.557
# I:avg_f1score: 0.171
# I:avg_intersection_len: 24.8

# %%
curt = datetime.now()
curt = str(curt.year)+str(curt.month)+str(curt.day)
with pd.ExcelWriter(f'./result_excel_filter/result_notbaseline_filter_{CLASSIFIER_STRING}_{curt}_partial2.xlsx') as writer:
    result_ova.to_excel(writer, sheet_name='ova_svm')
    result_ovo.to_excel(writer, sheet_name='ovo_svm')
